# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                  transcript        full_name
# bushh     Mr. Chief Justice, Mr. President, Vice Preside...   George H. Bush
# bushw1    President Clinton, distinguished guests and my...   George W. Bush
# bushw2    Vice President Cheney, Mr. Chief Justice, Pres...  George W. Bush2
# carter    For myself and for our Nation, I want to thank...     Jimmy Carter
# clinton1  My fellow citizens, today we celebrate the mys...     Bill Clinton
# clinton2  My fellow citizens, at this last Presidential ...    Bill Clinton2
# nixon1    Senator Dirksen, Mr. Chief Justice, Mr. Vice P...    Richard Nixon
# nixon2    Mr. Vice President, Mr. Speaker, Mr. Chief Jus...   Richard Nixon2
# obama1    I stand here today humbled by the task before ...     Barack Obama
# obama2    \r\nVice President Biden, Mr. Chief Justice,\r...    Barack Obama2
# reagan1   Senator Hatfield, Mr. Chief Justice, Mr. Presi...    Ronald Reagan
# reagan2   Senator Mathias, Chief Justice Burger, Vice Pr...   Ronald Reagan2
# trump     Chief Justice Roberts, President Carter, Presi...     Donald Trump

# %%
# Extract only Ali Wong's text
reagan1_text = data.transcript.loc['reagan1']
reagan1_text[:200]
# Out:
# "Senator Hatfield, Mr. Chief Justice, Mr. President, Vice President Bush, Vice President Mondale, Senator Baker, Speaker O'Neill, Reverend Moomaw, and my fellow citizens:\r\nTo a few of us here today thi"

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
reagan1_dict = markov_chain(reagan1_text)
reagan1_dict
# Out:
# {'Senator': ['Hatfield,', 'Baker,'],
#  'Hatfield,': ['Mr.'],
#  'Mr.': ['Chief', 'President,'],
#  'Chief': ['Justice,'],
#  'Justice,': ['Mr.'],
#  'President,': ['Vice', 'I'],
#  'Vice': ['President', 'President'],
#  'President': ['Bush,', 'Mondale,'],
#  'Bush,': ['Vice'],
#  'Mondale,': ['Senator'],
#  'Baker,': ['Speaker'],
#  'Speaker': ["O'Neill,"],
#  "O'Neill,": ['Reverend'],
#  'Reverend': ['Moomaw,'],
#  'Moomaw,': ['and'],
#  'and': ['my',
#   'most',
#   'yet',
#   'few',
#   'I',
#   'your',
#   'one',
#   'crushes',
#   'the',
#   'personal',
#   'keeps',
#   'our',
#   'economic',
#   'I,',
#   'greatest',
#   'of',
#   'out',
#   'racial',
#   'it',
#   'women',
#   'factories,',
#   'heal',
#   'truckdrivers.',
#   'all',
#   'fair',
#   'our',
#   'prosperous',
#   'the',
#   'reverse',
#   'influence',
#   'to',
#   'those',
#   'must',
#   'individual',
#   'the',
#   'assured',
#   'are',
#   'intrusion',
#   'excessive',
#   'our',
#   'our',
#   'out',
#   'then',
#   "they're",
#   'faith',
#   'opportunity.',
#   'families',
#   'whose',
#   'education.',
#   '"their"',
#   '"your,"',
#   'the',
#   'not',
#   'loving',
#   'provide',
#   'not',
#   'emphatic',
#   'reduced',
#   'feet,',
#   'to',
#   'on',
#   'the',
#   'liberty',
#   'our',
#   'a',
#   'allies',
#   'assure',
#   'firm',
#   'moral',
#   'women.',
#   'prey',
#   'for',
#   'I',
#   'good,',
#   'history.',
#   'on',
#   'halfway',
#   'in',
#   'jungles',
#   'do',
#   'so',
#   'our',
#   'to',
#   'will',
#   'thank'],
#  'my': ['fellow', 'intention', 'intention', 'utmost,'],
#  'fellow': ['citizens:\r\nTo', 'citizens', 'Americans,'],
#  'citizens:\r\nTo': ['a'],
#  'a': ['few',
#   'solemn',
#   'commonplace',
#   'miracle.\r\nMr.',
#   'watching',
#   'united',
#   'political',
#   'greater',
#   'fair',
#   'tax',
#   'limited',
#   'nation,',
#   'higher',
#   'special',
#   'healthy,',
#   'revived',
#   'strong',
#   'nation',
#   'government—not',
#   'greater',
#   'nation',
#   'fate',
#   'fate',
#   'time',
#   'handful',
#   'counter,',
#   'part',
#   'hand',
#   'man',
#   'beacon',
#   'failure',
#   'weapon',
#   'weapon',
#   'nation',
#   'day',
#   'magnificent',
#   'monumental',
#   'tiny',
#   'monument',
#   'hundred',
#   'place',
#   'young',
#   'small',
#   'message',
#   'diary.'],
#  'few': ['of', 'of'],
#  'of': ['us',
#   'our',
#   'authority',
#   'us',
#   'ma',
#   'our',
#   'our',
#   'great',
#   'the',
#   'millions',
#   'our',
#   'the',
#   'time.',
#   'freedom.\r\nIn',
#   'the',
#   'governing',
#   'us',
#   'government,',
#   'special',
#   'men',
#   'bigotry',
#   'runaway',
#   'this',
#   'a',
#   'our',
#   'the',
#   'government,',
#   'having',
#   'the',
#   'the',
#   'the',
#   'us',
#   'man',
#   'the',
#   'government.',
#   'national',
#   'factory',
#   'us',
#   'that',
#   'these',
#   'whom',
#   'this',
#   'this',
#   'your',
#   'presiding',
#   'the',
#   'government.',
#   'our',
#   'the',
#   'the',
#   '.',
#   'America.',
#   'millions',
#   'yourselves."\r\nWell,',
#   'today,',
#   'ourselves,',
#   'freedom',
#   'hope',
#   'our',
#   'freedom,',
#   'the',
#   'will.',
#   'never',
#   'the',
#   'free',
#   'thousands',
#   'prayer',
#   'prayer.\r\nThis',
#   'the',
#   'this',
#   'me,',
#   'our',
#   'humility',
#   'revolutionary',
#   'Independence',
#   'the',
#   'America',
#   'Abraham',
#   'Arlington',
#   'simple',
#   'David.',
#   'the',
#   'those',
#   'hero',
#   'earlier.',
#   'a',
#   'the',
#   'us',
#   'sacrifice',
#   'others'],
#  'us': ['here',
#   'stop',
#   'from',
#   'over',
#   'is',
#   'has',
#   'together,',
#   'when',
#   'take',
#   'special',
#   'need',
#   'to',
#   'believe,',
#   'no',
#   'if',
#   'begin',
#   'renew',
#   'renew',
#   'and',
#   'to',
#   'the'],
#  'here': ['today', 'in', 'than', 'in'],
#  'today': ['this', 'in', 'does'],
#  'this': ['is',
#   'every-4-year',
#   'tradition.',
#   'long',
#   'last',
#   'present',
#   'breed',
#   "administration's",
#   '"new',
#   'makes',
#   'land',
#   'freedom',
#   'blessed',
#   'administration,',
#   'industrial',
#   'day,',
#   'ceremony',
#   'West',
#   "city's",
#   'open',
#   'war.'],
#  'is': ['a',
#   'a',
#   'nothing',
#   'the',
#   'to',
#   'not',
#   'the',
#   'superior',
#   'capable',
#   'made',
#   'time',
#   'my',
#   'rather',
#   'no',
#   'time',
#   'quiet,',
#   'so',
#   'an',
#   'time',
#   'in',
#   'not',
#   'the',
#   'required',
#   'so',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a'],
#  'solemn': ['and'],
#  'most': ['momentous'],
#  'momentous': ['occasion,'],
#  'occasion,': ['and'],
#  'yet': ['in', 'unborn.'],
#  'in': ['the',
#   'the',
#   'the',
#   'the',
#   'maintaining',
#   'our',
#   'order',
#   'days,',
#   'the',
#   'and',
#   'short,',
#   'the',
#   'the',
#   'this',
#   'any',
#   'our',
#   'a',
#   'a',
#   'a',
#   'and',
#   'number,',
#   'themselves',
#   'an',
#   'speaking',
#   'fact',
#   'theory?\r\nCan',
#   'inches',
#   'danger,',
#   'our',
#   'the',
#   "today's",
#   'future',
#   'our',
#   'front',
#   'his',
#   'the',
#   'places',
#   'a',
#   'a',
#   '1917',
#   'ourselves',
#   'our'],
#  'the': ['history',
#   'Constitution',
#   'eyes',
#   'world,',
#   'transition',
#   'continuity',
#   'bulwark',
#   'longest',
#   'worst',
#   'struggling',
#   'fixed-income',
#   'lives',
#   'temporary',
#   'present.',
#   'capacity',
#   'past,',
#   'solution',
#   'problem.',
#   'people.',
#   'capacity',
#   'burden.',
#   'people,"',
#   'terror',
#   'productive',
#   'bounty',
#   'idealism',
#   'core',
#   'world.\r\nSo,',
#   'other',
#   'nations',
#   'Earth.',
#   'people.',
#   'growth',
#   'consent',
#   'governed.\r\nIt',
#   'size',
#   'Federal',
#   'distinction',
#   'powers',
#   'Federal',
#   'States',
#   'people.',
#   'Federal',
#   'States;',
#   'States',
#   'Federal',
#   'answer',
#   'energy',
#   'dignity',
#   'individual',
#   'intervention',
#   'creative',
#   'world',
#   'government',
#   'words',
#   'heroes',
#   'citizens',
#   'dreams,',
#   'hopes,',
#   'goals',
#   'compassion',
#   'problems',
#   'answer',
#   'oath',
#   'intention',
#   'dissolution',
#   "world's",
#   'days',
#   'roadblocks',
#   'balance',
#   'various',
#   'eve',
#   'greatest',
#   'Founding',
#   'Massachusetts',
#   'fortunes',
#   'important',
#   'happiness',
#   'liberty',
#   'Americans',
#   'world.',
#   'exemplar',
#   'enemies',
#   'highest',
#   'American',
#   'best',
#   'arsenals',
#   'world',
#   'will',
#   'first',
#   'Capitol.',
#   'end',
#   'giants',
#   'monument',
#   'stately',
#   'Reflecting',
#   'dignified',
#   'Lincoln',
#   'meaning',
#   'life',
#   'Potomac',
#   'far',
#   'sloping',
#   'price',
#   'kind',
#   'world',
#   'Chosin',
#   'famed',
#   'western',
#   'flyleaf',
#   'heading,',
#   'issue',
#   'whole',
#   'kind',
#   'problems'],
#  'history': ['of', 'that'],
#  'our': ['nation',
#   'fellow',
#   'Republic.\r\nThe',
#   'nation',
#   'national',
#   'economic',
#   'people.\r\nIdle',
#   'tax',
#   'future',
#   "children's",
#   'means,',
#   'problem;',
#   'concern',
#   'food,',
#   'streets,',
#   'mines',
#   'children,',
#   'homes,',
#   'system',
#   'strength,',
#   'side,',
#   'back.',
#   'present',
#   'lives',
#   'command,',
#   'determination,',
#   'courage,',
#   'strength.',
#   'faith',
#   'hope.\r\nWe',
#   'national',
#   'country',
#   'countrymen;',
#   'economy',
#   'punitive',
#   'first',
#   'struggle',
#   'children,',
#   "children's",
#   'own',
#   'freedom,',
#   'historic',
#   'support',
#   'friendship',
#   'own',
#   'national',
#   'adversaries',
#   'history',
#   'country.',
#   'freedom.\r\nEach',
#   'best',
#   'willingness',
#   'capacity'],
#  'nation': ['it', 'goes', 'that', 'to', 'under'],
#  'it': ['is',
#   'has',
#   'has',
#   'crosses',
#   'by',
#   'work—work',
#   'was',
#   'should',
#   'in'],
#  'commonplace': ['occurrence.'],
#  'occurrence.': ['The'],
#  'The': ['orderly', 'solutions', 'price', 'Declaration', 'Argonne,'],
#  'orderly': ['transfer'],
#  'transfer': ['of'],
#  'authority': ['as'],
#  'as': ['called',
#   'it',
#   'normal',
#   'our',
#   'individuals,',
#   'a',
#   'Americans',
#   "we've",
#   'we',
#   'to',
#   'no',
#   'some',
#   'we',
#   'having',
#   'a',
#   'the',
#   'Americans',
#   "you've",
#   'if'],
#  'called': ['for',
#   'Americans.\r\nWell,',
#   'Belleau',
#   'Vietnam.\r\nUnder',
#   'upon'],
#  'for': ['in',
#   'almost',
#   'all',
#   'their',
#   'the',
#   'only',
#   'a',
#   'all',
#   'so',
#   'this',
#   'us',
#   'independence',
#   'ourselves,',
#   'those',
#   'mutually',
#   'our',
#   'sale.\r\nAs',
#   'the',
#   'it,',
#   'it;',
#   'it,',
#   'conflict',
#   'that',
#   'us',
#   'our'],
#  'Constitution': ['routinely'],
#  'routinely': ['takes'],
#  'takes': ['place,'],
#  'place,': ['as'],
#  'has': ['for',
#   'not',
#   'become',
#   'the',
#   'been',
#   'a',
#   'no',
#   'ever',
#   'been',
#   'been',
#   'been'],
#  'almost': ['two'],
#  'two': ['centuries,'],
#  'centuries,': ['and'],
#  'stop': ['to'],
#  'to': ['think',
#   'know',
#   'carry',
#   'maintaining',
#   'a',
#   'shatter',
#   'guarantee',
#   'preserve',
#   'begin',
#   'act,',
#   'do',
#   'be',
#   'preserve',
#   'our',
#   'time',
#   'believe',
#   'be',
#   'government',
#   'govern',
#   'pay',
#   'work',
#   'work.',
#   'check',
#   'curb',
#   'demand',
#   'the',
#   'the',
#   'the',
#   'be',
#   'do',
#   'make',
#   'stand',
#   'the',
#   'why',
#   'a',
#   'pay',
#   'the',
#   'realize',
#   'limit',
#   'small',
#   'an',
#   'dream',
#   'look.',
#   'feed',
#   'be',
#   'make',
#   'reawaken',
#   'get',
#   'lighten',
#   'his',
#   'be',
#   'decide',
#   'act',
#   'do',
#   'ensure',
#   'impose',
#   'preserve',
#   'prevail',
#   'use',
#   'be',
#   'the',
#   'a',
#   'greatness',
#   'one',
#   'Thomas',
#   'heroism',
#   'only',
#   'the',
#   'go',
#   'France',
#   'carry',
#   'make.',
#   'believe',
#   'believe',
#   'perform',
#   'believe'],
#  'think': ['how', 'that'],
#  'how': ['unique', 'much'],
#  'unique': ['we'],
#  'we': ['really',
#   'accept',
#   'are',
#   'have',
#   'think',
#   'suffer',
#   'as',
#   'seek',
#   'can',
#   'begin,',
#   'look',
#   'achieved',
#   'unleashed',
#   'have',
#   'do.',
#   'do',
#   'love',
#   'solve',
#   'will',
#   'renew',
#   'will',
#   'will',
#   'will',
#   'will',
#   'do',
#   'have',
#   'must',
#   'as',
#   'stand.\r\nDirectly',
#   'are',
#   'can',
#   'believe'],
#  'really': ['are.'],
#  'are.': ['In'],
#  'In': ['the'],
#  'eyes': ['of'],
#  'ma': ['in'],
#  'world,': ['this'],
#  'every-4-year': ['ceremony'],
#  'ceremony': ['we', 'has'],
#  'accept': ['as'],
#  'normal': ['is'],
#  'nothing': ['less'],
#  'less': ['than'],
#  'than': ['a', 'any', 'has', 'in'],
#  'miracle.\r\nMr.': ['President,'],
#  'I': ['want',
#   'thank',
#   'do',
#   'do',
#   'have',
#   'could',
#   'speak—you,',
#   'did',
#   'will',
#   'believe',
#   'believe',
#   'think,',
#   'spoke',
#   'will',
#   'will',
#   'will',
#   'will',
#   'will'],
#  'want': ['our'],
#  'citizens': ['to', 'of'],
#  'know': ['how', 'where'],
#  'much': ['you', 'of', 'a'],
#  'you': ['did', 'have', 'and', 'depend'],
#  'did': ['to', 'not', 'not'],
#  'carry': ['on', 'a'],
#  'on': ['this',
#   'our',
#   'Earth,',
#   'Earth.',
#   'us',
#   'us',
#   'both',
#   'these',
#   'their',
#   'this',
#   'each',
#   'this',
#   'this',
#   'whose',
#   'the',
#   'Guadalcanal,',
#   'the',
#   'his',
#   'me'],
#  'tradition.': ['By'],
#  'By': ['your'],
#  'your': ['gracious', 'people', 'help', 'hopes,', 'goals', 'makeup.'],
#  'gracious': ['cooperation'],
#  'cooperation': ['in'],
#  'transition': ['process,'],
#  'process,': ['you'],
#  'have': ['shown',
#   'cast',
#   'piled',
#   'come',
#   'the',
#   'a',
#   'been',
#   'never',
#   'us',
#   'every',
#   'used',
#   'slowed',
#   'been',
#   'freedom.\r\nTo',
#   'the'],
#  'shown': ['a'],
#  'watching': ['world'],
#  'world': ['that', 'beyond.', 'is', 'do', 'on'],
#  'that': ['we',
#   'collectively,',
#   'same',
#   'society',
#   'government',
#   'has',
#   'provides',
#   'has',
#   'granted',
#   'the',
#   'price.\r\nIt',
#   'our',
#   'result',
#   "we're",
#   'will',
#   'will',
#   "we're",
#   'counter.',
#   'is',
#   'have',
#   'peace',
#   'if',
#   'strength.\r\nAbove',
#   'no',
#   'we',
#   'be',
#   'tens',
#   "I'm",
#   'this',
#   'has',
#   'on',
#   'Martin',
#   'together'],
#  'are': ['a',
#   'confronted',
#   'denied',
#   'going',
#   'the',
#   'a',
#   'proportionate',
#   'not',
#   'entrepreneurs',
#   'going',
#   'to',
#   'ready',
#   'potential',
#   'being',
#   'a',
#   'those',
#   'facing',
#   'Americans.\r\nGod'],
#  'united': ['people'],
#  'people': ['pledged', 'for', 'on'],
#  'pledged': ['to'],
#  'maintaining': ['a', 'the', 'full'],
#  'political': ['system', 'party'],
#  'system': ['which', 'which', 'and'],
#  'which': ['guarantees', 'is', 'penalizes', 'are', 'shows', 'rests', 'now'],
#  'guarantees': ['individual'],
#  'individual': ['liberty', 'genius', 'have'],
#  'liberty': ['to', 'of', 'for'],
#  'greater': ['degree', 'extent', 'strength'],
#  'degree': ['than'],
#  'any': ['other,', 'other'],
#  'other,': ['and'],
#  'thank': ['you', 'you.'],
#  'all': ['your', 'Americans', 'Americans', 'Americans', 'must', 'the', 'of'],
#  'help': ['in', 'me', 'we'],
#  'continuity': ['which'],
#  'bulwark': ['of'],
#  'Republic.\r\nThe': ['business'],
#  'business': ['of'],
#  'goes': ['forward.'],
#  'forward.': ['These'],
#  'These': ['United'],
#  'United': ['States'],
#  'States': ['are', 'or', 'created'],
#  'confronted': ['with'],
#  'with': ['an',
#   'public',
#   'no',
#   'no',
#   'itself',
#   'government.',
#   'us,',
#   'all',
#   'faith',
#   'the',
#   'loyalty.',
#   'his',
#   'its',
#   'the',
#   "God's"],
#  'an': ['economic', 'elite', 'inevitable', 'era', 'idea', 'unequivocal'],
#  'economic': ['affliction', 'decisions,', 'upheavals.\r\nYou', 'ills'],
#  'affliction': ['of'],
#  'great': ['proportions.', 'as', 'a', 'deeds,'],
#  'proportions.': ['We'],
#  'We': ['suffer',
#   'must',
#   'are',
#   'are',
#   'will',
#   'will',
#   'will',
#   'will',
#   'will',
#   'will',
#   'are',
#   'are'],
#  'suffer': ['from', 'have'],
#  'from': ['the', 'maintaining', 'the', 'unnecessary'],
#  'longest': ['and'],
#  'one': ['of', 'among', 'group', 'of', 'faces', 'side,', 'of', 'such'],
#  'worst': ['sustained'],
#  'sustained': ['inflations'],
#  'inflations': ['in'],
#  'national': ['history.', 'renewal.', 'life.\r\nNow,', 'security,'],
#  'history.': ['It', 'At'],
#  'It': ['distorts',
#   'threatens',
#   'knows',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'would',
#   'does'],
#  'distorts': ['our'],
#  'decisions,': ['penalizes'],
#  'penalizes': ['thrift,', 'successful'],
#  'thrift,': ['and'],
#  'crushes': ['the'],
#  'struggling': ['young'],
#  'young': ['and', 'man,'],
#  'fixed-income': ['elderly'],
#  'elderly': ['alike.'],
#  'alike.': ['It'],
#  'threatens': ['to'],
#  'shatter': ['the'],
#  'lives': ['of', 'that', 'ended'],
#  'millions': ['of', 'yet'],
#  'people.\r\nIdle': ['industries'],
#  'industries': ['have'],
#  'cast': ['workers'],
#  'workers': ['into'],
#  'into': ['unemployment,', 'infant'],
#  'unemployment,': ['human'],
#  'human': ['misery,'],
#  'misery,': ['and'],
#  'personal': ['indignity.'],
#  'indignity.': ['Those'],
#  'Those': ['who', 'who'],
#  'who': ['do',
#   'among',
#   'raise',
#   'say',
#   'create',
#   'might',
#   'do',
#   'share',
#   'are',
#   'practice',
#   'came',
#   'left'],
#  'do': ['work',
#   'whatever',
#   'away',
#   'not',
#   'believe',
#   'nothing.',
#   'what',
#   'not',
#   'so',
#   'not',
#   'have.',
#   'my'],
#  'work': ['are', 'means', 'of'],
#  'denied': ['a'],
#  'fair': ['return', 'play'],
#  'return': ['for'],
#  'their': ['labor', 'sovereignty,', "neighbors.\r\nI'm"],
#  'labor': ['by'],
#  'by': ['a', 'borrowing,', 'that', 'self-rule,', 'an', 'the', 'our', 'those'],
#  'tax': ['system', 'burden', 'burden.'],
#  'successful': ['achievement'],
#  'achievement': ['and'],
#  'keeps': ['us'],
#  'full': ['productivity.\r\nBut'],
#  'productivity.\r\nBut': ['great'],
#  'burden': ['is,'],
#  'is,': ['it'],
#  'not': ['kept',
#   'bound',
#   'go',
#   'the',
#   'create',
#   'my',
#   'over',
#   'ride',
#   'smother',
#   'stifle',
#   'believe',
#   'heroes,',
#   'love',
#   'just',
#   'take',
#   'miles,',
#   'to',
#   'now',
#   'use',
#   'for',
#   'surrender',
#   'be',
#   'have.',
#   'require'],
#  'kept': ['pace'],
#  'pace': ['with'],
#  'public': ['spending.'],
#  'spending.': ['For'],
#  'For': ['decades'],
#  'decades': ['we'],
#  'piled': ['deficit'],
#  'deficit': ['upon'],
#  'upon': ['deficit,', 'us', 'which', 'their', 'row', 'to'],
#  'deficit,': ['mortgaging'],
#  'mortgaging': ['our'],
#  'future': ['and', 'for', 'years'],
#  "children's": ['future', 'children.'],
#  'temporary': ['convenience'],
#  'convenience': ['of'],
#  'present.': ['To'],
#  'To': ['continue', 'paraphrase'],
#  'continue': ['this'],
#  'long': ['trend', 'neglected.'],
#  'trend': ['is'],
#  'guarantee': ['tremendous'],
#  'tremendous': ['social,'],
#  'social,': ['cultural,'],
#  'cultural,': ['political,'],
#  'political,': ['and'],
#  'upheavals.\r\nYou': ['and'],
#  'I,': ['as'],
#  'individuals,': ['can,'],
#  'can,': ['by'],
#  'borrowing,': ['live'],
#  'live': ['beyond'],
#  'beyond': ['our', 'the', 'the'],
#  'means,': ['but', 'and'],
#  'but': ['for', 'they', 'we', 'deep.', 'we', 'not'],
#  'only': ['a', 'a'],
#  'limited': ['period'],
#  'period': ['of'],
#  'time.': ['Why,'],
#  'Why,': ['then,'],
#  'then,': ['should', 'beyond'],
#  'should': ['we', 'never', 'not', 'be'],
#  'collectively,': ['as'],
#  'nation,': ["we're"],
#  "we're": ['not', 'sick—professionals,', 'too', 'in'],
#  'bound': ['by'],
#  'same': ['limitation?'],
#  'limitation?': ['We'],
#  'must': ['act',
#   'bear',
#   'be',
#   'be',
#   'share',
#   'share',
#   'provide',
#   'be',
#   'realize',
#   'win'],
#  'act': ['today', 'worthy'],
#  'order': ['to'],
#  'preserve': ['tomorrow.', 'this', 'our'],
#  'tomorrow.': ['And'],
#  'And': ['let', 'this', 'let', 'these', 'as', 'then,'],
#  'let': ['there', 'us', 'us', 'us'],
#  'there': ['be', 'will', 'are', 'will'],
#  'be': ['no',
#   'done',
#   'managed',
#   'equitable,',
#   'for',
#   'a',
#   'reminded',
#   'no',
#   'the',
#   'equal',
#   'taken',
#   'slow,',
#   'our',
#   'no',
#   'despaired',
#   'done',
#   'seen',
#   'the',
#   'reminded',
#   'misunderstood.',
#   'misjudged',
#   'understood',
#   'free.',
#   'fitting',
#   'declared'],
#  'no': ['misunderstanding:',
#   'one',
#   'one',
#   'sectional',
#   'barriers',
#   'power',
#   'misunderstanding,',
#   'other',
#   'coincidence',
#   'matter',
#   'compromise.\r\nOn',
#   'arsenal',
#   'weapon'],
#  'misunderstanding:': ['We'],
#  'going': ['to', 'in', 'to'],
#  'begin': ['to', 'an'],
#  'act,': ['beginning'],
#  'beginning': ['today.\r\nThe'],
#  'today.\r\nThe': ['economic'],
#  'ills': ['we'],
#  'come': ['upon'],
#  'over': ['several', 'us;', 'the'],
#  'several': ['decades.'],
#  'decades.': ['They'],
#  'They': ['will', 'will', 'are,', 'add'],
#  'will': ['not',
#   'go',
#   'go',
#   'be',
#   'be',
#   'fall',
#   'fall',
#   'be',
#   'propose',
#   'be',
#   'progress.',
#   'be',
#   'be',
#   'be',
#   'again',
#   'strengthen',
#   'match',
#   'strive',
#   'not',
#   'be',
#   'negotiate',
#   'not',
#   'act.',
#   'maintain',
#   'and',
#   'find',
#   'work,',
#   'save,',
#   'sacrifice,',
#   'endure,',
#   'fight',
#   'resolve'],
#  'go': ['away', 'away.', 'away', 'to'],
#  'away': ['in', 'because', 'with'],
#  'days,': ['weeks,'],
#  'weeks,': ['or'],
#  'or': ['months,',
#   'ethnic',
#   'discrimination.',
#   'to',
#   'ever.\r\nOur',
#   'no',
#   'Stars'],
#  'months,': ['but'],
#  'they': ['will', 'just', 'fall,', 'will', 'will'],
#  'away.': ['They'],
#  'because': ['we', 'here', "I'm"],
#  'Americans': ['have', 'with', 'back', 'from', 'of', 'do'],
#  'capacity': ['now,', 'to', 'to'],
#  'now,': ['as'],
#  "we've": ['had', 'been'],
#  'had': ['in', 'written'],
#  'past,': ['to'],
#  'whatever': ['needs'],
#  'needs': ['to'],
#  'done': ['to', 'before.', 'to'],
#  'last': ['and'],
#  'greatest': ['bastion', 'among'],
#  'bastion': ['of'],
#  'freedom.\r\nIn': ['this'],
#  'present': ['crisis,', 'troubles'],
#  'crisis,': ['government'],
#  'government': ['is', 'is', 'by', 'for,', 'has', 'and', 'back'],
#  'solution': ['to'],
#  'problem;': ['government'],
#  'problem.': ['From'],
#  'From': ['time'],
#  'time': ['to', "we've", 'to', 'for', 'when', 'to', 'in'],
#  'been': ['tempted',
#   'too',
#   'done',
#   'more',
#   'high,',
#   'unwilling',
#   'one',
#   'held,',
#   'told,',
#   'paid'],
#  'tempted': ['to'],
#  'believe': ['that', 'in', 'in', 'we,', 'God', 'in', 'in', 'that', 'that?'],
#  'society': ['has'],
#  'become': ['too'],
#  'too': ['complex', 'long', 'great'],
#  'complex': ['to'],
#  'managed': ['by'],
#  'self-rule,': ['that'],
#  'elite': ['group'],
#  'group': ['is', 'singled', 'that'],
#  'superior': ['to'],
#  'for,': ['by,'],
#  'by,': ['and'],
#  'people.': ['Well,', 'It', 'All', 'We'],
#  'Well,': ['if', 'our', 'the'],
#  'if': ['no', 'we', 'need', 'we', 'on', 'the'],
#  'among': ['us', 'us', 'the', 'the'],
#  'capable': ['of'],
#  'governing': ['himself,'],
#  'himself,': ['then'],
#  'then': ['who', 'the'],
#  'govern': ['someone'],
#  'someone': ['else?'],
#  'else?': ['All'],
#  'All': ['of', 'must', 'of'],
#  'together,': ['in'],
#  'out': ['of', 'to', 'of', 'a', 'of'],
#  'government,': ['must', 'which'],
#  'bear': ['the'],
#  'burden.': ['The', 'And'],
#  'solutions': ['we'],
#  'seek': ['must'],
#  'equitable,': ['with'],
#  'singled': ['out'],
#  'pay': ['a', 'that'],
#  'higher': ['price.\r\nWe'],
#  'price.\r\nWe': ['hear'],
#  'hear': ['much'],
#  'special': ['interest', 'interest', 'among', 'beauty'],
#  'interest': ['groups.', 'group'],
#  'groups.': ['Well,'],
#  'concern': ['must'],
#  'neglected.': ['It'],
#  'knows': ['no'],
#  'sectional': ['boundaries'],
#  'boundaries': ['or'],
#  'ethnic': ['and'],
#  'racial': ['divisions,'],
#  'divisions,': ['and'],
#  'crosses': ['political', 'or'],
#  'party': ['lines.'],
#  'lines.': ['It'],
#  'made': ['up'],
#  'up': ['of', 'on', 'to'],
#  'men': ['and', 'and'],
#  'women': ['who'],
#  'raise': ['our'],
#  'food,': ['patrol'],
#  'patrol': ['our'],
#  'streets,': ['man'],
#  'man': ['our', 'to', 'who', 'of'],
#  'mines': ['and'],
#  'factories,': ['teach'],
#  'teach': ['our'],
#  'children,': ['keep', 'and'],
#  'keep': ['our'],
#  'homes,': ['and'],
#  'heal': ['us', 'them'],
#  'when': ["we're", 'there', 'they', "they're"],
#  'sick—professionals,': ['industrialists,'],
#  'industrialists,': ['shopkeepers,'],
#  'shopkeepers,': ['clerks,'],
#  'clerks,': ['cabbies,'],
#  'cabbies,': ['and'],
#  'truckdrivers.': ['They'],
#  'are,': ['in'],
#  'short,': ['"We'],
#  '"We': ['the'],
#  'people,"': ['this'],
#  'breed': ['called'],
#  'Americans.\r\nWell,': ['this'],
#  "administration's": ['objective'],
#  'objective': ['will'],
#  'healthy,': ['vigorous,'],
#  'vigorous,': ['growing'],
#  'growing': ['economy'],
#  'economy': ['that', 'and'],
#  'provides': ['equal'],
#  'equal': ['opportunities', 'in'],
#  'opportunities': ['for'],
#  'barriers': ['born'],
#  'born': ['of'],
#  'bigotry': ['or'],
#  'discrimination.': ['Putting'],
#  'Putting': ['America'],
#  'America': ['back', 'out', 'will'],
#  'back': ['to', 'to', 'within'],
#  'means': ['putting', 'freeing'],
#  'putting': ['all'],
#  'work.': ['Ending'],
#  'Ending': ['inflation'],
#  'inflation': ['means'],
#  'freeing': ['all'],
#  'terror': ['of'],
#  'runaway': ['living'],
#  'living': ['costs.'],
#  'costs.': ['All'],
#  'share': ['in', 'in', 'our'],
#  'productive': ['work'],
#  '"new': ['beginning,"'],
#  'beginning,"': ['and'],
#  'bounty': ['of'],
#  'revived': ['economy.'],
#  'economy.': ['With'],
#  'With': ['the'],
#  'idealism': ['and'],
#  'play': ['which'],
#  'core': ['of'],
#  'strength,': ['we'],
#  'can': ['have', 'and', 'see', 'we', 'and'],
#  'strong': ['and'],
#  'prosperous': ['America,'],
#  'America,': ['at'],
#  'at': ['peace', 'times', 'our', 'restoring'],
#  'peace': ['with', 'is'],
#  'itself': ['and'],
#  'world.\r\nSo,': ['as'],
#  'begin,': ['let'],
#  'take': ['inventory.', 'the'],
#  'inventory.': ['We'],
#  'government—not': ['the'],
#  'other': ['way', 'people', 'place'],
#  'way': ['around.'],
#  'around.': ['And'],
#  'makes': ['us'],
#  'nations': ['of'],
#  'Earth.': ['Our', 'The'],
#  'Our': ['government', 'reluctance'],
#  'power': ['except'],
#  'except': ['that'],
#  'granted': ['it', 'to'],
#  'check': ['and'],
#  'reverse': ['the'],
#  'growth': ['of', 'of'],
#  'shows': ['signs'],
#  'signs': ['of'],
#  'having': ['grown', 'greater', 'to'],
#  'grown': ['beyond'],
#  'consent': ['of'],
#  'governed.\r\nIt': ['is'],
#  'intention': ['to', 'to', 'of'],
#  'curb': ['the'],
#  'size': ['and'],
#  'influence': ['of'],
#  'Federal': ['establishment',
#   'Government',
#   'Government',
#   'Government.\r\nNow,'],
#  'establishment': ['and'],
#  'demand': ['recognition'],
#  'recognition': ['of'],
#  'distinction': ['between'],
#  'between': ['the', 'the', 'battalions'],
#  'powers': ['granted'],
#  'Government': ['and', 'did', 'can'],
#  'those': ['reserved',
#   'who',
#   'neighbors',
#   'who',
#   'who',
#   'shrines',
#   'monuments',
#   'markers'],
#  'reserved': ['to'],
#  'need': ['to', 'be,'],
#  'reminded': ['that', 'that'],
#  'create': ['the', 'new'],
#  'States;': ['the'],
#  'created': ['the'],
#  'Government.\r\nNow,': ['so'],
#  'so': ['there',
#   'many',
#   'much,',
#   'help',
#   'much',
#   'they',
#   'we',
#   'formidable',
#   'many'],
#  'misunderstanding,': ["it's"],
#  "it's": ['not'],
#  'government.': ['It', 'It', 'Progress'],
#  'rather': ['to'],
#  'make': ['it', 'them'],
#  'work—work': ['with'],
#  'us,': ['not'],
#  'us;': ['to'],
#  'stand': ['by'],
#  'side,': ['not', 'the'],
#  'ride': ['on'],
#  'back.': ['Government'],
#  'provide': ['opportunity,', 'opportunity'],
#  'opportunity,': ['not'],
#  'smother': ['it;'],
#  'it;': ['foster', 'we'],
#  'foster': ['productivity,'],
#  'productivity,': ['not'],
#  'stifle': ['it.\r\nIf'],
#  'it.\r\nIf': ['we'],
#  'look': ['to'],
#  'answer': ['as', 'is'],
#  'why': ['for', "shouldn't"],
#  'many': ['years', 'thousands'],
#  'years': ['we', 'it'],
#  'achieved': ['so'],
#  'much,': ['prospered'],
#  'prospered': ['as'],
#  'Earth,': ['it'],
#  'was': ['because', 'killed', 'found'],
#  'land': ['we'],
#  'unleashed': ['the'],
#  'energy': ['and', 'at'],
#  'genius': ['of'],
#  'extent': ['than'],
#  'ever': ['been'],
#  'before.': ['Freedom'],
#  'Freedom': ['and'],
#  'dignity': ['of'],
#  'more': ['available'],
#  'available': ['and'],
#  'assured': ['here'],
#  'place': ['on', 'called'],
#  'price': ['for', 'that'],
#  'freedom': ['at', 'and'],
#  'times': ['has'],
#  'high,': ['but'],
#  'never': ['been', 'be', 'having'],
#  'unwilling': ['to'],
#  'price.\r\nIt': ['is'],
#  'coincidence': ['that'],
#  'troubles': ['parallel'],
#  'parallel': ['and'],
#  'proportionate': ['to'],
#  'intervention': ['and'],
#  'intrusion': ['in'],
#  'result': ['from'],
#  'unnecessary': ['and'],
#  'excessive': ['growth'],
#  'realize': ['that', 'that'],
#  'limit': ['ourselves'],
#  'ourselves': ['to', 'here', 'and'],
#  'small': ['dreams.', 'town'],
#  'dreams.': ["We're", 'Those'],
#  "We're": ['not,'],
#  'not,': ['as'],
#  'some': ['would'],
#  'would': ['have', 'be', 'understand'],
#  'believe,': ['doomed'],
#  'doomed': ['to'],
#  'inevitable': ['decline.'],
#  'decline.': ['I'],
#  'fate': ['that', 'that'],
#  'fall': ['on', 'on'],
#  'matter': ['what'],
#  'what': ['we', 'must'],
#  'do.': ['I'],
#  'nothing.': ['So,'],
#  'So,': ['with'],
#  'creative': ['energy'],
#  'command,': ['let'],
#  'era': ['of'],
#  'renewal.': ['Let'],
#  'Let': ['us', 'that'],
#  'renew': ['our', 'our', 'ourselves'],
#  'determination,': ['our'],
#  'courage,': ['and'],
#  'strength.': ['And'],
#  'faith': ['and', 'in', 'in'],
#  'hope.\r\nWe': ['have'],
#  'every': ['right', 'day'],
#  'right': ['to'],
#  'dream': ['heroic'],
#  'heroic': ['dreams.'],
#  'say': ['that', '"you"'],
#  'heroes,': ['they'],
#  'just': ["don't", 'in', 'taken'],
#  "don't": ['know'],
#  'where': ['to'],
#  'look.': ['You'],
#  'You': ['can', 'meet', 'are'],
#  'see': ['heroes'],
#  'heroes': ['every', 'across', 'of'],
#  'day': ['going', 'of'],
#  'factory': ['gates.'],
#  'gates.': ['Others,'],
#  'Others,': ['a'],
#  'handful': ['in'],
#  'number,': ['produce'],
#  'produce': ['enough'],
#  'enough': ['food'],
#  'food': ['to'],
#  'feed': ['all'],
#  'beyond.': ['You'],
#  'meet': ['heroes'],
#  'across': ['a'],
#  'counter,': ['and'],
#  "they're": ['on', 'sick,'],
#  'both': ['sides'],
#  'sides': ['of'],
#  'counter.': ['There'],
#  'There': ['are'],
#  'entrepreneurs': ['with'],
#  'themselves': ['and'],
#  'idea': ['who'],
#  'new': ['jobs,', 'wealth'],
#  'jobs,': ['new'],
#  'wealth': ['and'],
#  'opportunity.': ["They're"],
#  "They're": ['individuals'],
#  'individuals': ['and'],
#  'families': ['whose'],
#  'whose': ['taxes', 'voluntary', 'shoulders'],
#  'taxes': ['support'],
#  'support': ['the', 'church,', 'and'],
#  'voluntary': ['gifts'],
#  'gifts': ['support'],
#  'church,': ['charity,'],
#  'charity,': ['culture,'],
#  'culture,': ['art,'],
#  'art,': ['and'],
#  'education.': ['Their'],
#  'Their': ['patriotism', 'values', 'lives'],
#  'patriotism': ['is'],
#  'quiet,': ['but'],
#  'deep.': ['Their'],
#  'values': ['sustain'],
#  'sustain': ['our'],
#  'life.\r\nNow,': ['I'],
#  'used': ['the'],
#  'words': ['"they"'],
#  '"they"': ['and'],
#  '"their"': ['in'],
#  'speaking': ['of'],
#  'these': ['heroes.', 'will', 'principles', 'words:'],
#  'heroes.': ['I'],
#  'could': ['say'],
#  '"you"': ['and'],
#  '"your,"': ['because'],
#  "I'm": ['addressing', 'deeply'],
#  'addressing': ['the'],
#  'whom': ['I'],
#  'speak—you,': ['the'],
#  'blessed': ['land.'],
#  'land.': ['Your'],
#  'Your': ['dreams,'],
#  'dreams,': ['your', 'the'],
#  'hopes,': ['your', 'and'],
#  'goals': ['are', 'of'],
#  'administration,': ['so'],
#  'me': ['God.\r\nWe', 'alone."\r\nThe'],
#  'God.\r\nWe': ['shall'],
#  'shall': ['reflect'],
#  'reflect': ['the'],
#  'compassion': ['that'],
#  'part': ['of'],
#  'makeup.': ['How'],
#  'How': ['can'],
#  'love': ['our', 'our'],
#  'country': ['and', 'is'],
#  'countrymen;': ['and'],
#  'loving': ['them,'],
#  'them,': ['reach'],
#  'reach': ['out'],
#  'hand': ['when'],
#  'fall,': ['heal'],
#  'them': ['when', 'self-sufficient', 'of'],
#  'sick,': ['and'],
#  'opportunity': ['to'],
#  'self-sufficient': ['so'],
#  'fact': ['and'],
#  'theory?\r\nCan': ['we'],
#  'solve': ['the'],
#  'problems': ['confronting', 'which'],
#  'confronting': ['us?'],
#  'us?': ['Well,'],
#  'unequivocal': ['and'],
#  'emphatic': ['"yes."'],
#  '"yes."': ['To'],
#  'paraphrase': ['Winston'],
#  'Winston': ['Churchill,'],
#  'Churchill,': ['I'],
#  'oath': ["I've"],
#  "I've": ['just'],
#  'taken': ['with', 'aimed'],
#  'presiding': ['over'],
#  'dissolution': ['of'],
#  "world's": ['strongest'],
#  'strongest': ['economy.\r\nIn'],
#  'economy.\r\nIn': ['the'],
#  'days': ['ahead'],
#  'ahead': ['I'],
#  'propose': ['removing'],
#  'removing': ['the'],
#  'roadblocks': ['that'],
#  'slowed': ['our'],
#  'reduced': ['productivity.'],
#  'productivity.': ['Steps'],
#  'Steps': ['will'],
#  'aimed': ['at'],
#  'restoring': ['the'],
#  'balance': ['between'],
#  'various': ['levels'],
#  'levels': ['of'],
#  'Progress': ['may'],
#  'may': ['be'],
#  'slow,': ['measured'],
#  'measured': ['in'],
#  'inches': ['and'],
#  'feet,': ['not'],
#  'miles,': ['but'],
#  'progress.': ['It'],
#  'reawaken': ['this'],
#  'industrial': ['giant,'],
#  'giant,': ['to'],
#  'get': ['government'],
#  'within': ['its'],
#  'its': ['means,', 'row'],
#  'lighten': ['our'],
#  'punitive': ['tax'],
#  'first': ['priorities,', 'time'],
#  'priorities,': ['and'],
#  'principles': ['there'],
#  'compromise.\r\nOn': ['the'],
#  'eve': ['of'],
#  'struggle': ['for', 'depended'],
#  'independence': ['a'],
#  'might': ['have'],
#  'Founding': ['Fathers,'],
#  'Fathers,': ['Dr.'],
#  'Dr.': ['Joseph'],
#  'Joseph': ['Warren,'],
#  'Warren,': ['president'],
#  'president': ['of'],
#  'Massachusetts': ['Congress,'],
#  'Congress,': ['said'],
#  'said': ['to'],
#  'his': ['fellow', 'eloquence.', 'heart', 'job', 'body'],
#  'Americans,': ['"Our'],
#  '"Our': ['country'],
#  'danger,': ['but'],
#  'despaired': ['of'],
#  '.': ['.', '.', '.', 'On'],
#  'On': ['you', 'the'],
#  'depend': ['the'],
#  'fortunes': ['of'],
#  'America.': ['You'],
#  'decide': ['the'],
#  'important': ['questions'],
#  'questions': ['upon'],
#  'rests': ['the'],
#  'happiness': ['and', 'and'],
#  'unborn.': ['Act'],
#  'Act': ['worthy'],
#  'worthy': ['of', 'of'],
#  'yourselves."\r\nWell,': ['I'],
#  'we,': ['the'],
#  'today,': ['are'],
#  'ready': ['to', 'to'],
#  'ourselves,': ['ready', 'our'],
#  'ensure': ['happiness'],
#  'children.': ['And'],
#  'own': ['land,', 'sovereignty'],
#  'land,': ['we'],
#  'seen': ['as'],
#  'strength': ['throughout', 'to'],
#  'throughout': ['the'],
#  'world.': ['We'],
#  'again': ['be'],
#  'exemplar': ['of'],
#  'beacon': ['of'],
#  'hope': ['for'],
#  'now': ['have', 'or', 'confront'],
#  'freedom.\r\nTo': ['those'],
#  'neighbors': ['and'],
#  'allies': ['who'],
#  'freedom,': ['we', 'those'],
#  'strengthen': ['our'],
#  'historic': ['ties'],
#  'ties': ['and'],
#  'assure': ['them'],
#  'firm': ['commitment.'],
#  'commitment.': ['We'],
#  'match': ['loyalty'],
#  'loyalty': ['with'],
#  'loyalty.': ['We'],
#  'strive': ['for'],
#  'mutually': ['beneficial'],
#  'beneficial': ['relations.'],
#  'relations.': ['We'],
#  'use': ['our', 'that'],
#  'friendship': ['to'],
#  'impose': ['on'],
#  'sovereignty,': ['for'],
#  'sovereignty': ['is'],
#  'sale.\r\nAs': ['for'],
#  'enemies': ['of'],
#  'potential': ['adversaries,'],
#  'adversaries,': ['they'],
#  'highest': ['aspiration'],
#  'aspiration': ['of'],
#  'American': ['people.'],
#  'negotiate': ['for'],
#  'it,': ['sacrifice', 'now'],
#  'sacrifice': ['for', 'that'],
#  'surrender': ['for'],
#  'ever.\r\nOur': ['forbearance'],
#  'forbearance': ['should'],
#  'misunderstood.': ['Our'],
#  'reluctance': ['for'],
#  'conflict': ['should'],
#  'misjudged': ['as'],
#  'failure': ['of'],
#  'will.': ['When'],
#  'When': ['action'],
#  'action': ['is'],
#  'required': ['to'],
#  'security,': ['we'],
#  'act.': ['We'],
#  'maintain': ['sufficient'],
#  'sufficient': ['strength'],
#  'prevail': ['if'],
#  'be,': ['knowing'],
#  'knowing': ['that'],
#  'best': ['chance', 'effort'],
#  'chance': ['of'],
#  'strength.\r\nAbove': ['all,'],
#  'all,': ['we', 'why'],
#  'arsenal': ['or'],
#  'weapon': ['in', 'our', 'that'],
#  'arsenals': ['of'],
#  'formidable': ['as'],
#  'moral': ['courage'],
#  'courage': ['of'],
#  'free': ['men'],
#  'women.': ['It'],
#  'adversaries': ['in'],
#  "today's": ['world'],
#  'have.': ['It', 'Let'],
#  'understood': ['by'],
#  'practice': ['terrorism'],
#  'terrorism': ['and'],
#  'prey': ['upon'],
#  "neighbors.\r\nI'm": ['told'],
#  'told': ['that', 'that'],
#  'tens': ['of'],
#  'thousands': ['of', 'of'],
#  'prayer': ['meetings'],
#  'meetings': ['are'],
#  'being': ['held'],
#  'held': ['on'],
#  'day,': ['and'],
#  'deeply': ['grateful.'],
#  'grateful.': ['We'],
#  'under': ['God,', 'heavy', 'the'],
#  'God,': ['and'],
#  'God': ['intended'],
#  'intended': ['for'],
#  'free.': ['It'],
#  'fitting': ['and'],
#  'good,': ['I'],
#  'think,': ['if'],
#  'each': ['Inaugural'],
#  'Inaugural': ['Day'],
#  'Day': ['in'],
#  'declared': ['a'],
#  'prayer.\r\nThis': ['is'],
#  'held,': ['as'],
#  "you've": ['been'],
#  'told,': ['on'],
#  'West': ['Front'],
#  'Front': ['of'],
#  'Capitol.': ['Standing'],
#  'Standing': ['here,'],
#  'here,': ['one'],
#  'faces': ['a'],
#  'magnificent': ['vista,'],
#  'vista,': ['opening'],
#  'opening': ['up'],
#  "city's": ['special'],
#  'beauty': ['and'],
#  'At': ['the'],
#  'end': ['of'],
#  'open': ['mall'],
#  'mall': ['are'],
#  'shrines': ['to'],
#  'giants': ['on'],
#  'shoulders': ['we'],
#  'stand.\r\nDirectly': ['in'],
#  'front': ['of'],
#  'me,': ['the'],
#  'monument': ['to', 'to'],
#  'monumental': ['man,'],
#  'man,': ['George', 'Martin'],
#  'George': ['Washington,'],
#  'Washington,': ['father'],
#  'father': ['of'],
#  'country.': ['A'],
#  'A': ['man'],
#  'humility': ['who'],
#  'came': ['to'],
#  'greatness': ['reluctantly.'],
#  'reluctantly.': ['He'],
#  'He': ['led'],
#  'led': ['America'],
#  'revolutionary': ['victory'],
#  'victory': ['into'],
#  'infant': ['nationhood.'],
#  'nationhood.': ['Off'],
#  'Off': ['to'],
#  'stately': ['memorial'],
#  'memorial': ['to'],
#  'Thomas': ['Jefferson.'],
#  'Jefferson.': ['The'],
#  'Declaration': ['of'],
#  'Independence': ['flames'],
#  'flames': ['with'],
#  'eloquence.': ['And'],
#  'Reflecting': ['Pool,'],
#  'Pool,': ['the'],
#  'dignified': ['columns'],
#  'columns': ['of'],
#  'Lincoln': ['Memorial.'],
#  'Memorial.': ['Whoever'],
#  'Whoever': ['would'],
#  'understand': ['in'],
#  'heart': ['the'],
#  'meaning': ['of'],
#  'find': ['it'],
#  'life': ['of'],
#  'Abraham': ['Lincoln.\r\nBeyond'],
#  'Lincoln.\r\nBeyond': ['those'],
#  'monuments': ['to'],
#  'heroism': ['is'],
#  'Potomac': ['River,'],
#  'River,': ['and'],
#  'far': ['shore'],
#  'shore': ['the'],
#  'sloping': ['hills'],
#  'hills': ['of'],
#  'Arlington': ['National'],
#  'National': ['Cemetery,'],
#  'Cemetery,': ['with'],
#  'row': ['upon', 'of'],
#  'simple': ['white'],
#  'white': ['markers'],
#  'markers': ['bearing', 'is'],
#  'bearing': ['crosses'],
#  'Stars': ['of'],
#  'David.': ['They'],
#  'add': ['up'],
#  'tiny': ['fraction'],
#  'fraction': ['of'],
#  'paid': ['for'],
#  'freedom.\r\nEach': ['one'],
#  'kind': ['of', 'of'],
#  'hero': ['I'],
#  'spoke': ['of'],
#  'earlier.': ['Their'],
#  'ended': ['in'],
#  'places': ['called'],
#  'Belleau': ['Wood,'],
#  'Wood,': ['The'],
#  'Argonne,': ['Omaha'],
#  'Omaha': ['Beach,'],
#  'Beach,': ['Salerno,'],
#  'Salerno,': ['and'],
#  'halfway': ['around'],
#  'around': ['the'],
#  'Guadalcanal,': ['Tarawa,'],
#  'Tarawa,': ['Pork'],
#  'Pork': ['Chop'],
#  'Chop': ['Hill,'],
#  'Hill,': ['the'],
#  'Chosin': ['Reservoir,'],
#  'Reservoir,': ['and'],
#  'hundred': ['rice'],
#  'rice': ['paddies'],
#  'paddies': ['and'],
#  'jungles': ['of'],
#  'Vietnam.\r\nUnder': ['one'],
#  'such': ['marker'],
#  'marker': ['lies'],
#  'lies': ['a'],
#  'Martin': ['Treptow,', 'Treptow'],
#  'Treptow,': ['who'],
#  'left': ['his'],
#  'job': ['in'],
#  'town': ['barbershop'],
#  'barbershop': ['in'],
#  '1917': ['to'],
#  'France': ['with'],
#  'famed': ['Rainbow'],
#  'Rainbow': ['Division.'],
#  'Division.': ['There,'],
#  'There,': ['on'],
#  'western': ['front,'],
#  'front,': ['he'],
#  'he': ['was', 'had'],
#  'killed': ['trying'],
#  'trying': ['to'],
#  'message': ['between'],
#  'battalions': ['under'],
#  'heavy': ['artillery'],
#  'artillery': ["fire.\r\nWe're"],
#  "fire.\r\nWe're": ['told'],
#  'body': ['was'],
#  'found': ['a'],
#  'diary.': ['On'],
#  'flyleaf': ['under'],
#  'heading,': ['"My'],
#  '"My': ['Pledge,"'],
#  'Pledge,"': ['he'],
#  'written': ['these'],
#  'words:': ['"America'],
#  '"America': ['must'],
#  'win': ['this'],
#  'war.': ['Therefore'],
#  'Therefore': ['I'],
#  'work,': ['I'],
#  'save,': ['I'],
#  'sacrifice,': ['I'],
#  'endure,': ['I'],
#  'fight': ['cheerfully'],
#  ...}

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(reagan1_dict)
# Out:
# "Growing economy that on whose voluntary gifts support church, charity, culture, art, and opportunity. They're."
