# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\kevin\appdata\local\continuum\anaconda3\lib\site-packages (3.4.4)
# Requirement already satisfied: six in c:\users\kevin\appdata\local\continuum\anaconda3\lib\site-packages (from nltk) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pickle

def url_to_transcript(url):
    page = requests.get(url).text
    soup = BeautifulSoup(page, "lxml")
    text = [p.text for p in soup.find(class_="transcript-inner").find_all('p')]
    print(url)
    return text

urls = ['https://millercenter.org/the-presidency/presidential-speeches/january-20-1969-first-inaugural-address',
        'https://millercenter.org/the-presidency/presidential-speeches/january-20-1973-second-inaugural-address',
        'https://millercenter.org/the-presidency/presidential-speeches/january-20-1977-inaugural-address',
        'https://millercenter.org/the-presidency/presidential-speeches/january-20-1981-first-inaugural-address',
        'https://millercenter.org/the-presidency/presidential-speeches/january-21-1985-second-inaugural-address',
        'https://millercenter.org/the-presidency/presidential-speeches/january-20-1989-inaugural-address',
        'https://millercenter.org/the-presidency/presidential-speeches/january-20-1993-first-inaugural',
        'https://millercenter.org/the-presidency/presidential-speeches/january-20-1997-second-inaugural',
        'https://millercenter.org/the-presidency/presidential-speeches/january-20-2001-first-inaugural-address',
        'https://millercenter.org/the-presidency/presidential-speeches/january-20-2005-second-inaugural-address-0',
        'https://millercenter.org/the-presidency/presidential-speeches/january-20-2009-inaugural-address',
        'https://millercenter.org/the-presidency/presidential-speeches/january-21-2013-second-inaugural-address',
        'https://millercenter.org/the-presidency/presidential-speeches/january-20-2017-inaugural-address']

presidents = ['nixon1', 'nixon2', 'carter', 'reagan1', 'reagan2', 'bushh', 'clinton1', 'clinton2', 'bushw1', 'bushw2', 'obama1', 'obama2', 'trump']

# %%
transcripts = [url_to_transcript(u) for u in urls]
# Out:
# https://millercenter.org/the-presidency/presidential-speeches/january-20-1969-first-inaugural-address
# https://millercenter.org/the-presidency/presidential-speeches/january-20-1973-second-inaugural-address
# https://millercenter.org/the-presidency/presidential-speeches/january-20-1977-inaugural-address
# https://millercenter.org/the-presidency/presidential-speeches/january-20-1981-first-inaugural-address
# https://millercenter.org/the-presidency/presidential-speeches/january-21-1985-second-inaugural-address
# https://millercenter.org/the-presidency/presidential-speeches/january-20-1989-inaugural-address
# https://millercenter.org/the-presidency/presidential-speeches/january-20-1993-first-inaugural
# https://millercenter.org/the-presidency/presidential-speeches/january-20-1997-second-inaugural
# https://millercenter.org/the-presidency/presidential-speeches/january-20-2001-first-inaugural-address
# https://millercenter.org/the-presidency/presidential-speeches/january-20-2005-second-inaugural-address-0
# https://millercenter.org/the-presidency/presidential-speeches/january-20-2009-inaugural-address
# https://millercenter.org/the-presidency/presidential-speeches/january-21-2013-second-inaugural-address
# https://millercenter.org/the-presidency/presidential-speeches/january-20-2017-inaugural-address

# %%
for i, c in enumerate(presidents):
    with open("transcripts/" + c + ".txt", "wb") as file:
        pickle.dump(transcripts[i], file)

# %%
data = {}
for i, c in enumerate(presidents):
    with open("transcripts/" + c + ".txt", "rb") as file:
        data[c] = pickle.load(file)

# %%
data.keys()
# Out:
# dict_keys(['nixon1', 'nixon2', 'carter', 'reagan1', 'reagan2', 'bushh', 'clinton1', 'clinton2', 'bushw1', 'bushw2', 'obama1', 'obama2', 'trump'])

# ['Senator Dirksen, Mr. Chief Justice, Mr. Vice President, President Johnson, Vice President Humphrey, my fellow Americans--and my fellow citizens of the world community:\r\nI ask you to share with me today the majesty of this moment. In the orderly transfer of power, we celebrate the unity that keeps us free.\r\nEach moment in history is a fleeting time, precious and unique. But some stand out as moments of beginning, in which courses are set that shape decades or centuries.\r\nThis can be such a moment.\r\nForces now are converging that make possible, for the first time, the hope that many of man\'s deepest aspirations can at last be realized. The spiraling pace of change allows us to contemplate, within our own lifetime, advances that once would have taken centuries.\r\nIn throwing wide the horizons of space, we have discovered new horizons on earth.\r\nFor the first time, because the people of the world want peace, and the leaders of the world are afraid of war, the times are on the side of peace.\r\nEight years from now America will celebrate its 200th anniversary as a nation. Within the lifetime of most people now living, mankind will celebrate that great new year which comes only once in a thousand years--the beginning of the third millennium.\r\nWhat kind of nation we will be, what kind of world we will live in, whether we shape the future in the image of our hopes, is ours to determine by our actions and our choices.\r\nThe greatest honor history can bestow is the title of peacemaker. This honor now beckons America--the chance to help lead the world at last out of the valley of turmoil, and onto that high ground of peace that man has dreamed of since the dawn of civilization.\r\nIf we succeed, generations to come will say of us now living that we mastered our moment, that we helped make the world safe for mankind.\r\nThis is our summons to greatness.\r\nI believe the American people are ready to answer this call.\r\nThe second third of this century has been a time of proud achievement. We have made enormous strides in science and industry and agriculture. We have shared our wealth more broadly than ever. We have learned at last to manage a modern economy to assure its continued growth.\r\nWe have given freedom new reach, and we have begun to make its promise real for black as well as for white.\r\nWe see the hope of tomorrow in the youth of today. I know America\'s youth. I believe in them. We can be proud that they are better educated, more committed, more passionately driven by conscience than any generation in our history.\r\nNo people has ever been so close to the achievement of a just and abundant society, or so possessed of the will to achieve it. Because our strengths are so great, we can afford to appraise our weaknesses with candor and to approach them with hope.\r\nStanding in this same place a third of a century ago, Franklin Delano Roosevelt addressed a Nation ravaged by depression and gripped in fear. He could say in surveying the Nation\'s troubles: "They concern, thank God, only material things."\r\nOur crisis today is the reverse.\r\nWe have found ourselves rich in goods, but ragged in spirit; reaching with magnificent precision for the moon, but falling into raucous discord on earth.\r\nWe are caught in war, wanting peace. We are torn by division, wanting unity. We see around us empty lives, wanting fulfillment. We see tasks that need doing, waiting for hands to do them.\r\nTo a crisis of the spirit, we need an answer of the spirit.\r\nTo find that answer, we need only look within ourselves.\r\nWhen we listen to "the better angels of our nature," we find that they celebrate the simple things, the basic things--such as goodness, decency, love, kindness.\r\nGreatness comes in simple trappings.\r\nThe simple things are the ones most needed today if we are to surmount what divides us, and cement what unites us.\r\nTo lower our voices would be a simple thing.\r\nIn these difficult years, America has suffere ...

# %%
# We are going to change this to key: president, value: string format
def combine_text(list_of_text):
    combined_text = ' '.join(list_of_text)
    return combined_text

# %%
# Combine it!
data_combined = {key: [combine_text(value)] for (key, value) in data.items()}

# %%
# We can either keep it in dictionary format or put it into pandas dataset
import pandas as pd
pd.set_option('max_colwidth', 150)

data_df = pd.DataFrame.from_dict(data_combined).transpose()
data_df.columns = ['transcript']
data_df = data_df.sort_index()
data_df
# Out:
#                                                                                                                                                      transcript
# bushh     Mr. Chief Justice, Mr. President, Vice President Quayle, Senator Mitchell, Speaker Wright, Senator Dole, Congressman Michel, and fellow citizens, ...
# bushw1    President Clinton, distinguished guests and my fellow citizens, the peaceful transfer of authority is rare in history, yet common in our country. ...
. It must be earned. Our journey has never been one of short-cuts or settling for less. It has not been the path for the faint-hearted—for those who prefer leisure over work, or seek only the pleasures of riches and fame. Rather, it has been the risk-takers, the doers, the makers of things—some celebrated but more often men and women obscure in their labor, who have carried us up the long, rugged path towards prosperity and freedom.\r\nFor us, they packed up their few worldly possessions and traveled across oceans in search of a new life.\r\nFor us, they toiled in sweatshops and settled the West; endured the lash of the whip and plowed the hard earth.\r\nFor us, they fought and died, in places like Concord and Gettysburg; Normandy and Khe Sahn.\r\nTime and again these men and women struggled and sacrificed and worked till their hands were raw so that we might live a better life. They saw America as bigger than the sum of our individual ambitions; greater than all the differences of birth or wealth or faction.\r\nThis is the journey we continue today. We remain the most prosperous, powerful nation on Earth. Our workers are no less productive than when this crisis began. Our minds are no less inventive, our goods and services no less needed than they were last week or last month or last year. Our capacity remains undiminished. But our time of standing pat, of protecting narrow  ...

# %%
# Apply a first round of text cleaning techniques
import re
import string

def clean_text_round1(text):

    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

round1 = lambda x: clean_text_round1(x)

# %%
# Let's take a look at the updated text
data_clean = pd.DataFrame(data_df.transcript.apply(round1))
data_clean
# Out:
#                                                                                                                                                      transcript
# bushh     mr chief justice mr president vice president quayle senator mitchell speaker wright senator dole congressman michel and fellow citizens neighbors ...
# bushw1    president clinton distinguished guests and my fellow citizens the peaceful transfer of authority is rare in history yet common in our country with...
# bushw2    vice president cheney mr chief justice president carter president bush president clinton reverend clergy distinguished guests fellow citizens on t...
# carter    for myself and for our nation i want to thank my predecessor for all he has done to heal our land in this outward and physical ceremony we attest ...
# clinton1  my fellow citizens today we celebrate the mystery of american renewal this ceremony is held in the depth of winter but by the words we speak and t...
# clinton2  my fellow citizens at this last presidential inauguration of the  century let us lift our eyes toward the challenges that await us in the next cen...
# nixon1    senator dirksen mr chief justice mr vice president president johnson vice president humphrey my fellow americansand my fellow citizens of the worl...
# nixon2    mr vice president mr speaker mr chief justice senator cook mrs eisenhower and my fellow citizens of this great and good country we share together\...
# obama1    i stand here today humbled by the task before us grateful for the trust you have bestowed mindful of the sacrifices borne by our ancestors i thank...
# obama2    \r\nvice president biden mr chief justice\r\nmembers of the united states congress distinguished guests and fellow citizens  \r\n \r\neach time we...
# reagan1   senator hatfield mr chief justice mr president vice president bush vice president mondale senator baker speaker oneill reverend moomaw and my fell...
# reagan2   senator mathias chief justice burger vice president bush speaker oneill senator dole reverend clergy and members of my family and friends and my f...
# trump     chief justice roberts president carter president clinton president bush president obama fellow americans and people of the world thank you we the ...

# %%
# Apply a second round of cleaning
def clean_text_round2(text):
    text = re.sub('[''""...]', '', text)
    text = re.sub('\n', '', text)
    return text

round2 = lambda x: clean_text_round2(x)

# %%
# Let's taake a look at the updated text
data_clean = pd.DataFrame(data_clean.transcript.apply(round2))
data_clean
# Out:
#                                                                                                                                                      transcript
# bushh     mr chief justice mr president vice president quayle senator mitchell speaker wright senator dole congressman michel and fellow citizens neighbors ...
# bushw1    president clinton distinguished guests and my fellow citizens the peaceful transfer of authority is rare in history yet common in our country with...
# bushw2    vice president cheney mr chief justice president carter president bush president clinton reverend clergy distinguished guests fellow citizens on t...
# nixon1          0       1       0  ...    0          0           0        0
# nixon2          0       8       0  ...    0          0           0        0
# obama1          0       0       0  ...    1          0           0        0
# obama2          0       1       0  ...    0          0           0        0
# reagan1         1       0       0  ...    1          0           0        0
# reagan2         0       0       1  ...    2          0           0        1
# trump           0       0       0  ...    1          0           0        0
#
#           yielding  yields  young  youngest  youth  youve
# bushh            0       1      4         0      0      0
# bushw1           1       0      1         0      0      0
# bushw2           0       0      1         1      0      0
# carter           0       0      0         0      0      0
# clinton1         0       0      2         0      0      0
# clinton2         0       0      1         0      0      0
# nixon1           0       0      0         0      2      0
# nixon2           0       0      1         0      0      0
# obama1           0       0      1         0      0      0
# obama2           0       0      1         0      1      0
# reagan1          0       0      2         0      0      1
# reagan2          0       0      2         0      1      1
# trump            0       0      1         0      0      0
#
# [13 rows x 3372 columns]

# %%
# Let's pickle it for later use
data_dtm.to_pickle("dtm.pkl")

# %%
# Let's also pickle the cleaned data (before we put it in document-term matrix format) and the CountVectorizer object
data_clean.to_pickle('data_clean.pkl')
pickle.dump(cv, open ("cv.pkl", "wb"))

# %%
# Read the document term-matrix
import pandas as pd

data = pd.read_pickle('dtm.pkl')
data = data.transpose()
data.head()
# Out:
#              bushh  bushw1  bushw2  carter  clinton1  clinton2  nixon1  \
# abandon          0       0       2       0         0         0       0
# abandoned        0       0       0       0         0         0       0
# abandonment      0       1       0       0         0         0       0
# abiding          0       0       0       1         0         0       0
# ability          0       0       0       0         0         0       0
#
#              nixon2  obama1  obama2  reagan1  reagan2  trump
# abandon           0       0       0        0        0      0
# abandoned         0       1       0        0        0      0
# abandonment       0       0       0        0        0      0
# abiding           0       0       0        0        0      0
# ability           0       1       0        0        0      0

# %%
# Find the top 30 words said by each President
top_dict = {}
for c in data.columns:
    top = data[c].sort_values(ascending=False).head(30)
    top_dict[c]= list(zip(top.index, top.values))
    
top_dict
# Out:
# {'bushh': [('new', 14),
#   ('great', 10),
#   ('world', 10),
#   ('nation', 10),
#   ('free', 9),
#   ('good', 8),
#   ('things', 8),
#   ('hand', 8),
#   ('friends', 8),
#   ('time', 7),
#   ('need', 7),
#   ('today', 7),
#   ('work', 7),
#   ('america', 7),
#   ('day', 7),
#   ('people', 7),
#   ('old', 6),
#   ('president', 6),
#   ('mr', 6),
#   ('freedom', 6),
#   ('know', 6),
#   ('strong', 6),
#   ('dont', 6),
#   ('make', 6),
#   ('breeze', 5),
#   ('word', 5),
#   ('better', 5),
#   ('government', 5),
#   ('right', 5),
#   ('hope', 5)],
#  'bushw1': [('country', 9),
#   ('citizens', 9),
#   ('story', 9),
#   ('america', 8),
#   ('nation', 8),
#   ('know', 5),
#   ('common', 5),
#   ('freedom', 5),
#   ('new', 5),
#   ('courage', 5),
#   ('promise', 5),
#   ('nations', 5),
#   ('americans', 5),
#   ('public', 4),
#   ('ideals', 4),
#   ('duty', 4),
#   ('live', 4),
#   ('american', 4),
#   ('character', 4),
#   ('children', 4),
#   ('purpose', 4),
#   ('civility', 4),
#   ('time', 4),
#   ('work', 4),
#   ('power', 4),
#   ('best', 4),
#   ('government', 4),
#   ('god', 3),
#   ('deep', 3),
#   ('great', 3)],
#  'bushw2': [('freedom', 25),
#   ('liberty', 15),
#   ('america', 12),
#   ('nation', 9),
#   ('country', 8),
#   ('world', 8),
#   ('americas', 8),
#   ('americans', 8),
#   ('history', 7),
#   ('time', 7),
#   ('free', 7),
#   ('work', 6),
#   ('justice', 6),
#   ('day', 6),
#   ('know', 6),
#   ('people', 6),
#   ('hope', 6),
#   ('citizens', 6),
#   ('cause', 6),
#   ('seen', 6),
#   ('human', 6),
#   ('came', 5),
#   ('tyranny', 5),
#   ('rights', 5),
#   ('character', 4),
#   ('life', 4),
#   ('states', 4),
#   ('president', 4),
#   ('good', 4),
#   ('united', 4)],
#  'carter': [('nation', 10),
#   ('new', 9),
#   ('strength', 7),
#   ('spirit', 6),
#   ('people', 5),
#   ('dream', 5),
#   ('world', 5),
#   ('human', 5),
#   ('let', 4),
#   ('freedom', 4),
#   ('just', 4),
#   ('nations', 4),
#   ('moral', 3),
#   ('times', 3),
#   ('strong', 3),
#   ('best', 3),
#   ('say', 3),
#   ('president', 3),
#   ('rights', 3),
#   ('government', 3),
#   ('know', 3),
#   ('afford', 3),
#   ('ago', 2),
#   ('commitment', 2),
#   ('physical', 2),
#   ('time', 2),
#   ('ceremony', 2),
#   ('help', 2),
#   ('wisdom', 2),
#   ('enhance', 2)],
#  'clinton1': [('world', 18),
#   ('america', 15),
#   ('people', 12),
#   ('americans', 10),
#   ('today', 10),
#   ('let', 9),
#   ('new', 9),
#   ('change', 8),
#   ('time', 7),
#   ('work', 6),
#   ('fellow', 5),
#   ('nation', 5),
#   ('idea', 5),
#   ('generation', 4),
#   ('government', 4),
#   ('renewal', 4),
#   ('millions', 4),
#   ('democracy', 4),
#   ('season', 4),
#   ('american', 4),
#   ('americas', 4),
#   ('service', 4),
#   ('posterity', 3),
#   ('raised', 3),
#   ('resolve', 3),
#   ('children', 3),
#   ('renew', 3),
#   ('spring', 3),
#   ('responsibility', 3),
#   ('powerful', 3)],
#  'clinton2': [('new', 29),
#   ('century', 20),
#   ('nation', 13),
#   ('time', 12),
#   ('land', 11),
#   ('america', 11),
#   ('people', 11),
#   ('government', 10),
#   ('world', 10),
#   ('promise', 10),
#   ('let', 9),
#   ('american', 9),
#   ('work', 8),
#   ('citizens', 8),
#   ('fellow', 7),
#   ('americans', 7),
#   ('great', 6),
#   ('lives', 6),
#   ('children', 6),
#   ('worlds', 5),
#   ('human', 5),
#   ('power', 5),
#   ('today', 5),
#   ('strong', 5),
#   ('come', 5),
#   ('yes', 4),
#   ('greatest', 4),
#   ('democracy', 4),
#   ('dream', 4),
#   ('union', 4)],
#  'nixon1': [('world', 12),
#   ('peace', 12),
#   ('people', 12),
#   ('let', 11),
#   ('know', 10),
#   ('make', 9),
#   ('voices', 8),
#   ('earth', 8),
#   ('new', 8),
#   ('man', 7),
#   ('need', 7),
#   ('moment', 6),
#   ('forward', 6),
#   ('today', 5),
#   ('great', 5),
#   ('time', 5),
#   ('spirit', 5),
#   ('destiny', 5),
#   ('god', 5),
#   ('government', 5),
#   ('reach', 4),
#   ('shall', 4),
#   ('nation', 4),
#   ('nations', 4),
#   ('america', 4),
#   ('heard', 4),
#   ('simple', 4),
#   ('history', 4),
#   ('come', 4),
#   ('life', 4)],
#  'nixon2': [('let', 21),
#   ('peace', 19),
#   ('world', 16),
#   ('new', 15),
#   ('america', 12),
#   ('responsibility', 11),
#   ('government', 10),
#   ('home', 9),
#   ('abroad', 8),
#   ('nation', 8),
#   ('americas', 8),
#   ('years', 7),
#   ('history', 7),
#   ('policies', 7),
#   ('great', 7),
#   ('role', 7),
#   ('better', 7),
#   ('make', 7),
#   ('shall', 7),
#   ('right', 6),
#   ('just', 6),
#   ('help', 6),
#   ('nations', 6),
#   ('time', 6),
#   ('people', 5),
#   ('responsibilities', 5),
#   ('era', 5),
#   ('progress', 5),
#   ('come', 5),
#   ('act', 5)],
#  'obama1': [('nation', 12),
#   ('new', 11),
#   ('america', 8),
#   ('today', 7),
#   ('people', 7),
#   ('let', 7),
#   ('common', 6),
#   ('time', 6),
#   ('work', 6),
#   ('generation', 5),
#   ('world', 5),
#   ('know', 5),
#   ('spirit', 5),
#   ('day', 5),
#   ('long', 4),
#   ('meet', 4),
#   ('peace', 4),
#   ('come', 4),
#   ('women', 4),
#   ('crisis', 4),
#   ('end', 4),
#   ('words', 4),
#   ('men', 4),
#   ('seek', 4),
#   ('things', 4),
#   ('greater', 4),
#   ('power', 4),
#   ('carried', 3),
#   ('nations', 3),
#   ('jobs', 3)],
#  'obama2': [('applause', 25),
#   ('people', 11),
#   ('time', 10),
#   ('america', 8),
#   ('make', 7),
#   ('country', 7),
#   ('american', 6),
#   ('journey', 6),
#   ('equal', 6),
#   ('new', 6),
#   ('nation', 6),
#   ('today', 6),
#   ('freedom', 6),
#   ('generation', 6),
#   ('citizens', 6),
#   ('creed', 5),
#   ('just', 5),
#   ('believe', 5),
#   ('liberty', 5),
#   ('years', 5),
#   ('god', 5),
#   ('complete', 5),
#   ('requires', 5),
#   ('government', 4),
#   ('act', 4),
#   ('life', 4),
#   ('americans', 4),
#   ('words', 4),
#   ('work', 4),
#   ('oath', 4)],
#  'reagan1': [('government', 17),
#   ('believe', 10),
#   ('people', 9),
#   ('americans', 9),
#   ('time', 8),
#   ('freedom', 8),
#   ('world', 8),
#   ('work', 7),
#   ('america', 6),
#   ('nation', 6),
#   ('man', 6),
#   ('let', 6),
#   ('president', 5),
#   ('today', 5),
#   ('national', 5),
#   ('called', 5),
#   ('act', 5),
#   ('strength', 5),
#   ('heroes', 5),
#   ('means', 4),
#   ('day', 4),
#   ('dreams', 4),
#   ('economic', 4),
#   ('economy', 4),
#   ('away', 4),
#   ('special', 4),
#   ('great', 4),
#   ('history', 4),
#   ('price', 4),
#   ('states', 4)],
#  'reagan2': [('people', 16),
#   ('world', 14),
#   ('government', 14),
#   ('freedom', 13),
#   ('time', 10),
#   ('human', 9),
#   ('new', 9),
#   ('history', 9),
#   ('peace', 8),
#   ('years', 8),
#   ('god', 8),
#   ('america', 8),
#   ('let', 7),
#   ('american', 7),
#   ('progress', 6),
#   ('weapons', 6),
#   ('nuclear', 6),
#   ('national', 6),
#   ('earth', 6),
#   ('citizens', 6),
#   ('americans', 6),
#   ('reduce', 5),
#   ('today', 5),
#   ('dignity', 5),
#   ('economy', 5),
#   ('union', 5),
#   ('governments', 5),
#   ('great', 5),
#   ('heart', 5),
#   ('work', 5)],
#  'trump': [('america', 17),
#   ('american', 12),
#   ('people', 9),
#   ('country', 9),
#   ('nation', 9),
#   ('world', 6),
#   ('new', 6),
#   ('great', 6),
#   ('protected', 5),
#   ('president', 5),
#   ('today', 5),
#   ('right', 5),
#   ('make', 5),
#   ('dreams', 5),
#   ('god', 4),
#   ('jobs', 4),
#   ('wealth', 4),
#   ('heart', 4),
#   ('citizens', 4),
#   ('bring', 4),
#   ('americans', 4),
#   ('power', 4),
#   ('factories', 3),
#   ('left', 3),
#   ('capital', 3),
#   ('countries', 3),
#   ('foreign', 3),
#   ('let', 3),
#   ('day', 3),
#   ('united', 3)]}

# %%
# Print the top 15 words said by each president
for presidents, top_words in top_dict.items():
    print(presidents)
    print(', '.join([word for word, count in top_words[0:14]]))
    print('---')
# Out:
# bushh
# new, great, world, nation, free, good, things, hand, friends, time, need, today, work, america
# ---
# bushw1
# country, citizens, story, america, nation, know, common, freedom, new, courage, promise, nations, americans, public
# ---
# bushw2
# freedom, liberty, america, nation, country, world, americas, americans, history, time, free, work, justice, day
# ---
# carter
# nation, new, strength, spirit, people, dream, world, human, let, freedom, just, nations, moral, times
# ---
# clinton1
# world, america, people, americans, today, let, new, change, time, work, fellow, nation, idea, generation
# ---
# clinton2
# new, century, nation, time, land, america, people, government, world, promise, let, american, work, citizens
# ---
# nixon1
# world, peace, people, let, know, make, voices, earth, new, man, need, moment, forward, today
# ---
# nixon2
# let, peace, world, new, america, responsibility, government, home, abroad, nation, americas, years, history, policies
# ---
# obama1
# nation, new, america, today, people, let, common, time, work, generation, world, know, spirit, day
# ---
# obama2
# applause, people, time, america, make, country, american, journey, equal, new, nation, today, freedom, generation
# ---
# reagan1
# government, believe, people, americans, time, freedom, world, work, america, nation, man, let, president, today
# ---
# reagan2
# people, world, government, freedom, time, human, new, history, peace, years, god, america, let, american
# ---
# trump
# america, american, people, country, nation, world, new, great, protected, president, today, right, make, dreams
# ---

# %%
# Look at the most common top words ---> add them to the stop word list
from collections import Counter

# Let's first pull out the top 30 words for each President
words = []
for presidents in data.columns:
    top = [word for (word, count) in top_dict[presidents]]
    for t in top:
        words.append(t)
        
words
# Out:
# ['new',
#  'great',
#  'world',
#  'nation',
#  'free',
#  'good',
#  'things',
#  'hand',
#  'friends',
#  'time',
#  'need',
#  'today',
#  'work',
#  'america',
#  'day',
#  'people',
#  'old',
#  'president',
#  'mr',
#  'freedom',
#  'know',
#  'strong',
#  'dont',
#  'make',
#  'breeze',
#  'word',
#  'better',
#  'government',
#  'right',
#  'hope',
#  'country',
#  'citizens',
#  'story',
#  'america',
#  'nation',
#  'know',
#  'common',
#  'freedom',
#  'new',
#  'courage',
#  'promise',
#  'nations',
#  'americans',
#  'public',
#  'ideals',
#  'duty',
#  'live',
#  'american',
#  'character',
#  'children',
#  'purpose',
#  'civility',
#  'time',
#  'work',
#  'power',
#  'best',
#  'government',
#  'god',
#  'deep',
#  'great',
#  'freedom',
#  'liberty',
#  'america',
#  'nation',
#  'country',
#  'world',
#  'americas',
#  'americans',
#  'history',
#  'time',
#  'free',
#  'work',
#  'justice',
#  'day',
#  'know',
#  'people',
#  'hope',
#  'citizens',
#  'cause',
#  'seen',
#  'human',
#  'came',
#  'tyranny',
#  'rights',
#  'character',
#  'life',
#  'states',
#  'president',
#  'good',
#  'united',
#  'nation',
#  'new',
#  'strength',
#  'spirit',
#  'people',
#  'dream',
#  'world',
#  'human',
#  'let',
#  'freedom',
#  'just',
#  'nations',
#  'moral',
#  'times',
#  'strong',
#  'best',
#  'say',
#  'president',
#  'rights',
#  'government',
#  'know',
#  'afford',
#  'ago',
#  'commitment',
#  'physical',
#  'time',
#  'ceremony',
#  'help',
#  'wisdom',
#  'enhance',
#  'world',
#  'america',
#  'people',
#  'americans',
#  'today',
#  'let',
#  'new',
#  'change',
#  'time',
#  'work',
#  'fellow',
#  'nation',
#  'idea',
#  'generation',
#  'government',
#  'renewal',
#  'millions',
#  'democracy',
#  'season',
#  'american',
#  'americas',
#  'service',
#  'posterity',
#  'raised',
#  'resolve',
#  'children',
#  'renew',
#  'spring',
#  'responsibility',
#  'powerful',
#  'new',
#  'century',
#  'nation',
#  'time',
#  'land',
#  'america',
#  'people',
#  'government',
#  'world',
#  'promise',
#  'let',
#  'american',
#  'work',
#  'citizens',
#  'fellow',
#  'americans',
#  'great',
#  'lives',
#  'children',
#  'worlds',
#  'human',
#  'power',
#  'today',
#  'strong',
#  'come',
#  'yes',
#  'greatest',
#  'democracy',
#  'dream',
#  'union',
#  'world',
#  'peace',
#  'people',
#  'let',
#  'know',
#  'make',
#  'voices',
#  'earth',
#  'new',
#  'man',
#  'need',
#  'moment',
#  'forward',
#  'today',
#  'great',
#  'time',
#  'spirit',
#  'destiny',
#  'god',
#  'government',
#  'reach',
#  'shall',
#  'nation',
#  'nations',
#  'america',
#  'heard',
#  'simple',
#  'history',
#  'come',
#  'life',
#  'let',
#  'peace',
#  'world',
#  'new',
#  'america',
#  'responsibility',
#  'government',
#  'home',
#  'abroad',
#  'nation',
#  'americas',
#  'years',
#  'history',
#  'policies',
#  'great',
#  'role',
#  'better',
#  'make',
#  'shall',
#  'right',
#  'just',
#  'help',
#  'nations',
#  'time',
#  'people',
#  'responsibilities',
#  'era',
#  'progress',
#  'come',
#  'act',
#  'nation',
#  'new',
#  'america',
#  'today',
#  'people',
#  'let',
#  'common',
#  'time',
#  'work',
#  'generation',
#  'world',
#  'know',
#  'spirit',
#  'day',
#  'long',
#  'meet',
#  'peace',
#  'come',
#  'women',
#  'crisis',
#  'end',
#  'words',
#  'men',
#  'seek',
#  'things',
#  'greater',
#  'power',
#  'carried',
#  'nations',
#  'jobs',
#  'applause',
#  'people',
#  'time',
#  'america',
#  'make',
#  'country',
#  'american',
#  'journey',
#  'equal',
#  'new',
#  'nation',
#  'today',
#  'freedom',
#  'generation',
#  'citizens',
#  'creed',
#  'just',
#  'believe',
#  'liberty',
#  'years',
#  'god',
#  'complete',
#  'requires',
#  'government',
#  'act',
#  'life',
#  'americans',
#  'words',
#  'work',
#  'oath',
#  'government',
#  'believe',
#  'people',
#  'americans',
#  'time',
#  'freedom',
#  'world',
#  'work',
#  'america',
#  'nation',
#  'man',
#  'let',
#  'president',
#  'today',
#  'national',
#  'called',
#  'act',
#  'strength',
#  'heroes',
#  'means',
#  'day',
#  'dreams',
#  'economic',
#  'economy',
#  'away',
#  'special',
#  'great',
#  'history',
#  'price',
#  'states',
#  'people',
#  'world',
#  'government',
#  'freedom',
#  'time',
#  'human',
#  'new',
#  'history',
#  'peace',
#  'years',
#  'god',
#  'america',
#  'let',
#  'american',
#  'progress',
#  'weapons',
#  'nuclear',
#  'national',
#  'earth',
#  'citizens',
#  'americans',
#  'reduce',
#  'today',
#  'dignity',
#  'economy',
#  'union',
#  'governments',
#  'great',
#  'heart',
#  'work',
#  'america',
#  'american',
#  'people',
#  'country',
#  'nation',
#  'world',
#  'new',
#  'great',
#  'protected',
#  'president',
#  'today',
#  'right',
#  'make',
#  'dreams',
#  'god',
#  'jobs',
#  'wealth',
#  'heart',
#  'citizens',
#  'bring',
#  'americans',
#  'power',
#  'factories',
#  'left',
#  'capital',
#  'countries',
#  'foreign',
#  'let',
#  'day',
#  'united']

# %%
# Let's aggregate this list and identify the most common words along with how many routines they occur in 
Counter(words).most_common()
# Out:
# [('nation', 12),
#  ('time', 12),
#  ('america', 12),
#  ('people', 12),
#  ('new', 11),
#  ('world', 11),
#  ('government', 10),
#  ('today', 9),
#  ('work', 9),
#  ('let', 9),
#  ('great', 8),
#  ('americans', 8),
#  ('freedom', 7),
#  ('know', 6),
#  ('citizens', 6),
#  ('american', 6),
#  ('day', 5),
#  ('president', 5),
#  ('make', 5),
#  ('nations', 5),
#  ('god', 5),
#  ('history', 5),
#  ('country', 4),
#  ('power', 4),
#  ('human', 4),
#  ('come', 4),
#  ('peace', 4),
#  ('strong', 3),
#  ('right', 3),
#  ('children', 3),
#  ('americas', 3),
#  ('life', 3),
#  ('spirit', 3),
#  ('just', 3),
#  ('generation', 3),
#  ('years', 3),
#  ('act', 3),
#  ('free', 2),
#  ('good', 2),
#  ('things', 2),
#  ('need', 2),
#  ('better', 2),
#  ('hope', 2),
#  ('common', 2),
#  ('promise', 2),
#  ('character', 2),
#  ('best', 2),
#  ('liberty', 2),
#  ('rights', 2),
#  ('states', 2),
#  ('united', 2),
#  ('strength', 2),
#  ('dream', 2),
#  ('help', 2),
#  ('fellow', 2),
#  ('democracy', 2),
#  ('responsibility', 2),
#  ('union', 2),
#  ('earth', 2),
#  ('man', 2),
#  ('shall', 2),
#  ('progress', 2),
#  ('words', 2),
#  ('jobs', 2),
#  ('believe', 2),
#  ('national', 2),
#  ('dreams', 2),
#  ('economy', 2),
#  ('heart', 2),
#  ('hand', 1),
#  ('friends', 1),
#  ('old', 1),
#  ('mr', 1),
#  ('dont', 1),
#  ('breeze', 1),
#  ('word', 1),
#  ('story', 1),
#  ('courage', 1),
#  ('public', 1),
#  ('ideals', 1),
#  ('duty', 1),
#  ('live', 1),
#  ('purpose', 1),
#  ('civility', 1),
#  ('deep', 1),
#  ('justice', 1),
#  ('cause', 1),
#  ('seen', 1),
#  ('came', 1),
#  ('tyranny', 1),
#  ('moral', 1),
#  ('times', 1),
#  ('say', 1),
#  ('afford', 1),
#  ('ago', 1),
#  ('commitment', 1),
#  ('physical', 1),
#  ('ceremony', 1),
#  ('wisdom', 1),
#  ('enhance', 1),
#  ('change', 1),
#  ('idea', 1),
#  ('renewal', 1),
#  ('millions', 1),
#  ('season', 1),
#  ('service', 1),
#  ('posterity', 1),
#  ('raised', 1),
#  ('resolve', 1),
#  ('renew', 1),
#  ('spring', 1),
#  ('powerful', 1),
#  ('century', 1),
#  ('land', 1),
#  ('lives', 1),
#  ('worlds', 1),
#  ('yes', 1),
#  ('greatest', 1),
#  ('voices', 1),
#  ('moment', 1),
#  ('forward', 1),
#  ('destiny', 1),
#  ('reach', 1),
#  ('heard', 1),
#  ('simple', 1),
#  ('home', 1),
#  ('abroad', 1),
#  ('policies', 1),
#  ('role', 1),
#  ('responsibilities', 1),
#  ('era', 1),
#  ('long', 1),
#  ('meet', 1),
#  ('women', 1),
#  ('crisis', 1),
#  ('end', 1),
#  ('men', 1),
#  ('seek', 1),
#  ('greater', 1),
#  ('carried', 1),
#  ('applause', 1),
#  ('journey', 1),
#  ('equal', 1),
#  ('creed', 1),
#  ('complete', 1),
#  ('requires', 1),
#  ('oath', 1),
#  ('called', 1),
#  ('heroes', 1),
#  ('means', 1),
#  ('economic', 1),
#  ('away', 1),
#  ('special', 1),
#  ('price', 1),
#  ('weapons', 1),
#  ('nuclear', 1),
#  ('reduce', 1),
#  ('dignity', 1),
#  ('governments', 1),
#  ('protected', 1),
#  ('wealth', 1),
#  ('bring', 1),
#  ('factories', 1),
#  ('left', 1),
#  ('capital', 1),
#  ('countries', 1),
#  ('foreign', 1)]

# %%
#If more than half the Presidents have it as a top word, exclude it from the list
add_stop_words = [word for word, count in Counter(words).most_common() if count > 6]
add_stop_words
# Out:
# ['nation',
#  'time',
#  'america',
#  'people',
#  'new',
#  'world',
#  'government',
#  'today',
#  'work',
#  'let',
#  'great',
#  'americans',
#  'freedom']

# %%
# Let's update our document-term matrix with new list of stop words
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer

# Read in cleaned data
data_clean = pd.read_pickle('data_clean.pkl')

# Add new stop words
stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)

# Recreate document-term matrix
cv = CountVectorizer(stop_words=stop_words)
data_cv = cv.fit_transform(data_clean.transcript)
data_stop = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_stop.index = data_clean.index

# Pickle it for later use
import pickle
pickle.dump(cv, open("cv_stop.pkl", "wb"))
data_stop.to_pickle("dtm_stop.pkl")

# %%
# Let's make some word clouds!
# Terminal Anaconda Prompt: conda install -c conda-forge wordcloud
from wordcloud import WordCloud

wc = WordCloud(stopwords=stop_words, background_color="white", colormap="Dark2", max_font_size=150, random_state=42)

# %%
# Reset the output dimensions
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [16, 16]

full_names = ['Richard Nixon', 'Richard Nixon2', 'Jimmy Carter', 
              'Ronald Reagan', 'Ronald Reagan2', 'George H Bush', 'Bill Clinton', 'Bill Clinton2', 'George W Bush', 'George W Bush2', 'Barrack Obama', 'Barrack Obama2', 'Donald Trump']

#Create subplots for each president
for index, presidents in enumerate(data.columns):
    wc.generate(data_clean.transcript[presidents])
    
    plt.subplot(4, 4, index+1)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(full_names[index])
    
plt.show()

# %%
# Find the number of unique words that each President uses

# Identify the non-zero items in the document-term matrix, meaning that the word occurs at least once
unique_list = []
for presidents in data.columns:
    uniques = data[presidents].nonzero()[0].size
    unique_list.append(uniques)

# Create a new dataframe that contains this unique word count
data_words = pd.DataFrame(list(zip(full_names, unique_list)), columns=['presidents', 'unique_words'])
data_unique_sort = data_words.sort_values(by='unique_words')
data_unique_sort
# Out:
# C:\Users\kevin\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#         presidents  unique_words
# 3    Ronald Reagan           347
# 7    Bill Clinton2           394
# 12    Donald Trump           422
# 1   Richard Nixon2           455
# 4   Ronald Reagan2           467
# 5    George H Bush           569
# 6     Bill Clinton           586
# 0    Richard Nixon           593
# 2     Jimmy Carter           598
# 9   George W Bush2           641
# 10   Barrack Obama           686
# 11  Barrack Obama2           708
# 8    George W Bush           749

# %%
# Calculate the words per minute of each President

# Find the total number of words that a President uses
total_list = []
for presidents in data.columns:
    totals = sum(data[presidents])
    total_list.append(totals)
    
# Comedy special run times from IMDB, in minutes
run_times = [20, 18, 19, 23, 23, 63, 15, 30, 14, 21, 22, 21, 55]

# Let's add some columns to our dataframe
data_words['total_words'] = total_list
data_words['run_times'] = run_times
data_words['words_per_minute'] = data_words['total_words'] / data_words['run_times']

# Sort the dataframe by words per minute to see who talks the slowest and fastest
data_wpm_sort = data_words.sort_values(by='words_per_minute')
data_wpm_sort
# Out:
#         presidents  unique_words  total_words  run_times  words_per_minute
# 12    Donald Trump           422          620         55         11.272727
# 5    George H Bush           569          952         63         15.111111
# 3    Ronald Reagan           347          467         23         20.304348
# 7    Bill Clinton2           394          742         30         24.733333
# 4   Ronald Reagan2           467          682         23         29.652174
# 1   Richard Nixon2           455          683         18         37.944444
# 9   George W Bush2           641          937         21         44.619048
# 10   Barrack Obama           686         1012         22         46.000000
# 0    Richard Nixon           593          979         20         48.950000
# 2     Jimmy Carter           598          937         19         49.315789
# 11  Barrack Obama2           708         1133         21         53.952381
# 6     Bill Clinton           586          892         15         59.466667
# 8    George W Bush           749         1031         14         73.642857

# %%
# Let's read in our document-term matrix
import pandas as pd
import pickle

data = pd.read_pickle('dtm_stop.pkl')
data
# Out:
#           abandon  abandoned  abandonment  abiding  ability  able  abolished  \
# bushh           0          0            0        0        0     0          0
# bushw1          0          0            1        0        0     0          0
# bushw2          2          0            0        0        0     0          0
# carter          0          0            0        1        0     0          0
# clinton1        0          0            0        0        0     1          0
# clinton2        0          0            0        0        0     0          1
# nixon1          0          0            0        0        0     0          0
# nixon2          0          0            0        0        0     1          0
# obama1          0          1            0        0        1     0          0
# obama2          0          0            0        0        0     0          0
# reagan1         0          0            0        0        0     0          0
# reagan2         0          0            0        0        0     0          0
# trump           0          0            0        0        0     0          0
#
#           abraham  abroad  absent  ...  yes  yesterday  yesterdays  yielded  \
# bushh           0       0       0  ...    2          0           0        0
# bushw1          0       0       0  ...    0          0           0        0
# bushw2          1       0       0  ...    0          1           0        0
# carter          0       1       0  ...    0          0           0        0
# clinton1        0       1       0  ...    1          0           1        0
# clinton2        0       0       0  ...    4          0           0        0
# nixon1          0       1       0  ...    0          0           0        0
# abroad                8       0       1        0        0      0
# absent                0       0       0        0        1      0
# absolute              0       0       0        0        0      0
# absolutism            0       0       1        0        0      0
# abundance             1       0       0        0        0      0
# abundant              0       0       0        0        1      0
# abuse                 0       0       0        0        1      0
# accept                1       1       0        1        0      1
# accepted              0       0       0        0        0      0
# accomplished          0       0       0        0        1      0
# accomplishment        0       0       0        0        0      0
# accomplishments       0       0       0        0        0      0
# account               0       1       0        0        0      0
# accumulate            0       0       0        0        0      0
# achieve               0       1       0        0        1      0
# achieved              0       0       0        1        0      0
# achievement           0       0       0        1        0      0
# achievements          0       0       0        0        0      0
# acrimony              0       0       0        0        0      0
# act                   5       1       4        5        1      0
# acted                 0       0       0        0        1      0
# acting                0       0       1        0        0      0
# action                0       1       1        1        0      2
# actions               0       0       0        0        0      0
# activism              0       0       0        0        0      0
# acts                  0       0       0        0        0      0
# adams                 0       0       0        0        1      0
# add                   0       0       0        1        0      0
# addiction             0       0       0        0        0      0
# addressed             0       0       0        0        0      0
# addressing            0       0       0        1        0      0
# adequate              0       0       0        0        1      0
# adjust                0       0       0        0        0      0
# administration        0       0       0        1        0      1
# administrations       0       0       0        1        0      0
# admonition            0       0       0        0        0      0
# adopted               1       0       0        0        0      0
# advance               0       1       2        0        0      0
# advances              0       0       0        0        0      0
# advancing             0       1       0        0        0      0
# advantage             1       0       0        0        0      0
# adventure             0       0       0        0        0      0

# %%
# We're going to put the term-document matrix into a new gensim format, from df --> sparse matrix --> gensim corpus
sparse_counts = scipy.sparse.csr_matrix(tdm)
corpus = matutils.Sparse2Corpus(sparse_counts)

# %%
# Gensim also requires dictionary of the all terms and their respective location in the term-document matrix
cv = pickle.load(open("cv_stop.pkl", "rb"))
id2word = dict((v, k) for k, v in cv.vocabulary_.items())

# %%
# Now that we have the corpus (term-document matrix) and id2word (dictionary of location: term),
# we need to specify two other parameters as well - the number of topics and the number of passes
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=2, passes=50)
lda.print_topics()
# Out:
# [(0,
#   '0.005*"country" + 0.005*"make" + 0.004*"know" + 0.004*"american" + 0.004*"president" + 0.004*"citizens" + 0.003*"liberty" + 0.003*"god" + 0.003*"free" + 0.003*"life"'),
#  (1,
#   '0.006*"peace" + 0.005*"century" + 0.004*"history" + 0.004*"american" + 0.004*"years" + 0.004*"come" + 0.003*"responsibility" + 0.003*"better" + 0.003*"human" + 0.003*"promise"')]

# %%
# LDA for num_topics = 4
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=4, passes=50)
lda.print_topics()
# Out:
# [(0,
#   '0.005*"american" + 0.005*"make" + 0.005*"peace" + 0.004*"president" + 0.004*"god" + 0.004*"earth" + 0.004*"man" + 0.004*"history" + 0.004*"need" + 0.004*"know"'),
#  (1,
#   '0.006*"strength" + 0.005*"spirit" + 0.004*"dream" + 0.004*"human" + 0.003*"nations" + 0.003*"just" + 0.003*"afford" + 0.003*"moral" + 0.003*"rights" + 0.003*"best"'),
#  (2,
#   '0.011*"applause" + 0.010*"peace" + 0.006*"make" + 0.005*"responsibility" + 0.005*"years" + 0.005*"just" + 0.004*"home" + 0.004*"country" + 0.004*"abroad" + 0.004*"americas"'),
#  (3,
#   '0.006*"century" + 0.006*"citizens" + 0.005*"liberty" + 0.005*"promise" + 0.005*"country" + 0.004*"know" + 0.004*"americas" + 0.004*"american" + 0.004*"day" + 0.004*"power"')]

# %%
# LDA for num_topics = 5
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics


# %%
# Create a new document-term matrix using only nouns
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer

# Re-add the additional stop words since we are recreating the document-term matrix
add_stop_words = ['like', 'im', 'know', 'just', 'dont', 'thats', 'right', 'people',
                  'youre', 'got', 'gonna', 'time', 'think', 'yeah', 'said']
stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)

# Recreate a document-term matrix with only nouns
cvn = CountVectorizer(stop_words=stop_words)
data_cvn = cvn.fit_transform(data_nouns.transcript)
data_dtmn = pd.DataFrame(data_cvn.toarray(), columns=cvn.get_feature_names())
data_dtmn.index = data_nouns.index
data_dtmn
# Out:
#           abandonment  ability  abraham  absolutism  abundance  abuse  \
# bushh               0        0        0           0          0      0
# bushw1              1        0        0           0          0      1
# bushw2              0        0        1           0          0      0
# carter              0        0        0           0          0      0
# clinton1            0        0        0           0          0      0
# clinton2            0        0        0           0          0      0
# nixon1              0        0        0           0          0      0
# nixon2              0        0        0           0          1      0
# obama1              0        1        0           0          0      0
# obama2              0        0        0           1          0      0
# reagan1             0        0        1           0          0      0
# reagan2             0        0        0           0          0      0
# trump               0        0        0           0          0      0
#
#           accomplishment  accomplishments  account  achievement  ...  worry  \
# bushh                  0                0        1            0  ...      0
# bushw1                 1                0        0            0  ...      0
# bushw2                 0                0        0            1  ...      0
# carter                 0                1        0            0  ...      0
# clinton1               0                0        0            0  ...      1
# clinton2               0                0        0            1  ...      0
# nixon1                 0                0        0            2  ...      0
# nixon2                 0                0        0            0  ...      0
# obama1                 0                0        0            0  ...      0
# obama2                 0                0        0            0  ...      0
# reagan1                0                0        0            1  ...      0
# reagan2                0                0        0            0  ...      0
# trump                  0                0        0            0  ...      0
#
#           worthy  year  years  yearsthe  yes  yesterday  yesterdays  youth  \
# bushh          0     0      2         0    1          0           0      0
# bushw1         0     0      2         0    0          0           0      0
# bushw2         0     0      3         0    0          1           0      0
# carter         0     1      1         0    0          0           0      0
# clinton1       0     0      0         0    0          0           1      0
# clinton2       0     0      3         0    3          0           0      0
# nixon1         0     1      4         1    0          0           0      2
# nixon2         0     2      7         0    0          0           0      0
# obama1         0     2      1         0    0          0           0      0
# obama2         0     0      5         0    0          0           0      0
# reagan1        2     0      2         0    1          0           0      0
# reagan2        0     1      7         0    1          0           0      1
# trump          0     0      2         0    0          0           0      0
#
#           youve
# bushh         0
# bushw1        0
# bushw2        0
# carter        0
# clinton1      0
# clinton2      0
# nixon1        0
# nixon2        0
# obama1        0
# obama2        0
# reagan1       1
# reagan2       0
# trump         0
#
# [13 rows x 1758 columns]

# %%
# Create the gensim corpus
corpusn = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmn.transpose()))

# Create the vocabulary dictionary
id2wordn = dict((v, k) for k, v in cvn.vocabulary_.items())

# %%
# Let's start with 2 topics
ldan = models.LdaModel(corpus=corpusn, num_topics=2, id2word=id2wordn, passes=50)
ldan.print_topics()
# Out:
# [(0,
#   '0.013*"nation" + 0.007*"spirit" + 0.006*"america" + 0.005*"world" + 0.005*"today" + 0.005*"strength" + 0.004*"nations" + 0.004*"day" + 0.004*"freedom" + 0.003*"generation"'),
#  (1,
#   '0.019*"world" + 0.014*"nation" + 0.013*"government" + 0.012*"america" + 0.012*"freedom" + 0.010*"today" + 0.009*"peace" + 0.008*"americans" + 0.008*"country" + 0.008*"citizens"')]

# %%
# Let's try topics = 4
ldan = models.LdaModel(corpus=corpusn, num_topics=4, id2word=id2wordn, passes=50)
ldan.print_topics()
# Out:
# [(0,
#   '0.020*"world" + 0.017*"nation" + 0.015*"government" + 0.013*"america" + 0.011*"today" + 0.010*"peace" + 0.009*"freedom" + 0.008*"americans" + 0.007*"country" + 0.007*"history"'),
#  (1,
#   '0.026*"freedom" + 0.016*"liberty" + 0.010*"nation" + 0.009*"country" + 0.009*"americans" + 0.009*"world" + 0.007*"history" + 0.007*"america" + 0.006*"justice" + 0.006*"citizens"'),
#  (2,
#   '0.001*"world" + 0.001*"freedom" + 0.001*"today" + 0.001*"america" + 0.001*"nation" + 0.001*"government" + 0.001*"americans" + 0.001*"history" + 0.001*"peace" + 0.001*"president"'),
#  (3,
#   '0.001*"world" + 0.001*"nation" + 0.001*"freedom" + 0.001*"today" + 0.001*"america" + 0.001*"government" + 0.001*"americans" + 0.001*"country" + 0.001*"liberty" + 0.001*"mercy"')]

# %%
# Let's create a function to pull out nouns from a string of text
def nouns_adj(text):
    '''Given a string of text, tokenize the text and pull out only the nouns and adjectives.'''
    is_noun_adj = lambda pos: pos[:2] == 'NN' or pos[:2] == 'JJ'
    tokenized = word_tokenize(text)
    nouns_adj = [word for (word, pos) in pos_tag(tokenized) if is_noun_adj(pos)] 
    return ' '.join(nouns_adj)

# %%
# Apply the nouns function to the transcripts to filter only on nouns
data_nouns_adj = pd.DataFrame(data_clean.transcript.apply(nouns_adj))
data_nouns_adj
# Out:
#                                                                                                                                                      transcript
# bushh     mr chief justice mr president vice president quayle senator mitchell speaker senator dole congressman michel fellow citizens neighbors friends man...
# bushw1    president clinton guests fellow citizens peaceful transfer authority rare history common country simple oath old traditions new beginnings i i tha...
# bushw2    vice president cheney mr chief justice president carter president president clinton clergy guests citizens day law ceremony durable wisdom constit...
# carter    nation i predecessor land outward physical ceremony inner spiritual strength nation high school miss julia coleman times unchanging principles bib...
# clinton1  fellow citizens today mystery american renewal ceremony depth winter words world spring spring reborn worlds oldest democracy vision courage ameri...
# clinton2  fellow citizens last presidential inauguration century eyes challenges next century great good fortune time chance edge new century new millennium...
# nixon1    senator dirksen mr chief justice mr vice president president johnson vice president fellow americansand fellow citizens world community share toda...
# nixon2    mr vice president mr speaker mr chief justice senator cook mrs eisenhower fellow citizens great good country share years america spirit prospect e...
# obama1    i today task trust mindful sacrifices ancestors president bush service nation generosity cooperation transition fortyfour americans presidential o...
# obama2    vice president mr chief justice members united states guests fellow citizens time president witness strength constitution promise democracy nation...
# reagan1   senator mr chief justice mr president vice president bush vice president mondale senator baker speaker moomaw fellow citizens few today solemn mom...
# reagan2   senator mathias chief justice burger vice president bush speaker dole reverend clergy members family friends fellow citizens day presence time abs...
# trump     chief justice roberts president carter president clinton president president fellow americans people world thank citizens america great national e...

# %%
# Create a new document-term matrix using only nouns and adjectives, also remove common words with max_df
cvna = CountVectorizer(stop_words=stop_words, max_df=.8)
data_cvna = cvna.fit_transform(data_nouns_adj.transcript)
data_dtmna = pd.DataFrame(data_cvna.toarray(), columns=cvna.get_feature_names())
data_dtmna.index = data_nouns_adj.index
data_dtmna
# Out:
#           abandonment  ability  able  abraham  absent  absolute  absolutism  \
# bushh               0        0     0        0       0         0           0
# bushw1              1        0     0        0       0         0           0
# bushw2              0        0     0        1       0         0           0
# carter              0        0     0        0       0         1           0
# clinton1            0        0     1        0       0         0           0
# clinton2            0        0     0        0       0         0           0
# nixon1              0        0     0        0       0         0           0
# nixon2              0        0     1        0       0         0           0
# obama1              0        1     0        0       0         0           0
# obama2              0        0     0        0       0         0           1
# reagan1             0        0     0        1       0         0           0
# reagan2             0        0     0        0       1         0           0
# trump               0        0     0        0       0         0           0
#
#           abundance  abundant  abuse  ...  wrong  year  yearsthe  yes  \
# bushh             0         0      0  ...      0     0         0    1
# bushw1            0         0      1  ...      1     0         0    0
# bushw2            0         0      0  ...      1     0         0    0
# carter            0         0      0  ...      0     1         0    0
# clinton1          0         0      0  ...      1     0         0    0
# clinton2          0         0      0  ...      1     0         0    3
# nixon1            0         1      0  ...      0     1         1    0
# nixon2            1         0      0  ...      1     2         0    0
# obama1            0         0      0  ...      1     2         0    0
# obama2            0         0      0  ...      0     0         0    0
# reagan1           0         0      0  ...      0     0         0    1
# reagan2           0         1      0  ...      0     1         0    1
# trump             0         0      0  ...      0     0         0    0
#
#           yesterday  yesterdays  yielded  youngest  youth  youve
# bushh             0           0        0         0      0      0
# bushw1            0           0        0         0      0      0
# bushw2            1           0        0         1      0      0
# carter            0           0        0         0      0      0
# clinton1          0           1        0         0      0      0
# clinton2          0           0        0         0      0      0
# nixon1            0           0        0         0      2      0
# nixon2            0           0        0         0      0      0
# obama1            0           0        0         0      0      0
# obama2            0           0        0         0      0      0
# reagan1           0           0        0         0      0      1
# reagan2           0           0        1         0      1      0
# trump             0           0        0         0      0      0
#
# [13 rows x 2258 columns]

# %%
# Create the gensim corpus
corpusna = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmna.transpose()))

# Create the vocabulary dictionary
id2wordna = dict((v, k) for k, v in cvna.vocabulary_.items())

# %%
# Let's start with 2 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=2, id2word=id2wordna, passes=50)
ldana.print_topics()
# Out:
# [(0,
#   '0.007*"americans" + 0.006*"century" + 0.005*"promise" + 0.004*"responsibility" + 0.004*"children" + 0.004*"land" + 0.004*"spirit" + 0.004*"americas" + 0.004*"home" + 0.004*"work"'),
#  (1,
#   '0.006*"americans" + 0.006*"human" + 0.006*"liberty" + 0.005*"work" + 0.004*"best" + 0.004*"justice" + 0.004*"hand" + 0.004*"times" + 0.004*"things" + 0.004*"old"')]

# %%
# Let's try 3 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=3, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.007*"man" + 0.005*"god" + 0.005*"americans" + 0.005*"voices" + 0.004*"moment" + 0.003*"national" + 0.003*"spirit" + 0.003*"words" + 0.003*"opportunity" + 0.003*"economy"'),
#  (1,
#   '0.006*"americans" + 0.005*"spirit" + 0.005*"old" + 0.005*"things" + 0.004*"human" + 0.004*"work" + 0.004*"common" + 0.004*"god" + 0.004*"children" + 0.004*"man"'),
#  (2,
#   '0.009*"century" + 0.008*"americans" + 0.008*"americas" + 0.007*"liberty" + 0.006*"promise" + 0.006*"responsibility" + 0.006*"work" + 0.005*"home" + 0.005*"land" + 0.005*"human"')]

# %%
# Let's try 5 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=5, id2word=id2wordna, passes=100)
ldana.print_topics()
# Out:
# [(0,
#   '0.009*"americans" + 0.007*"national" + 0.006*"human" + 0.006*"man" + 0.006*"god" + 0.006*"economy" + 0.006*"federal" + 0.005*"economic" + 0.004*"states" + 0.004*"progress"'),
#  (1,
#   '0.011*"century" + 0.009*"liberty" + 0.008*"americans" + 0.007*"promise" + 0.006*"land" + 0.006*"americas" + 0.006*"work" + 0.005*"human" + 0.005*"common" + 0.004*"spirit"'),
#  (2,
#   '0.007*"spirit" + 0.005*"god" + 0.005*"voices" + 0.005*"equal" + 0.005*"moment" + 0.005*"man" + 0.004*"words" + 0.004*"generation" + 0.004*"dream" + 0.004*"strong"'),
#  (3,
#   '0.008*"story" + 0.008*"americans" + 0.005*"courage" + 0.005*"children" + 0.004*"dreams" + 0.004*"small" + 0.004*"public" + 0.004*"common" + 0.004*"promise" + 0.004*"jobs"'),
#  (4,
#   '0.009*"responsibility" + 0.008*"home" + 0.007*"old" + 0.007*"americas" + 0.006*"americans" + 0.005*"place" + 0.005*"strong" + 0.005*"friends" + 0.005*"mr" + 0.005*"things"')]

# %%
# Let's take a look at which topics each transcript contains
corpus_transformed = ldana[corpusna]
list(zip([a for [(a,b)] in corpus_transformed], data_dtmna.index))
# Out:
# [(4, 'bushh'),
#  (3, 'bushw1'),
#  (1, 'bushw2'),
#  (2, 'carter'),
#  (4, 'clinton1'),
#  (1, 'clinton2'),
#  (2, 'nixon1'),
#  (4, 'nixon2'),
#  (1, 'obama1'),
#  (2, 'obama2'),
#  (0, 'reagan1'),
#  (0, 'reagan2'),
#  (3, 'trump')]
